# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhatamian/PY/blob/main/socialreasearch2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
us_df = pd.read_csv('US Police shootings in from 2015-22.csv')

# %%
us_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   1          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   2    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   3  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   4     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   5   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# 0  Not fleeing        False   -123.122    47.247                True
# 1  Not fleeing        False   -122.892    45.487                True
# 2  Not fleeing        False    -97.281    37.695                True
# 3  Not fleeing        False   -122.422    37.763                True
# 4  Not fleeing        False   -104.692    40.384                True

# %% [markdown]
# **Dataset Items:**
#
# * **id:** Serial No
# * **name:** Name of the victim
# * **date:** Date of the occurance
# * **manner_of_death:** In which way the victim died
# * **armed:** Used weapon of the victim
# * **age:** Age of the victim
# * **gender:** Gender of the victim
# * **race:** Race of the victim
# * **city:** City of the occurance
# * **state:** State of the occurance
# * **signs_of_mental_illness:** Either victim shows sign of mental illness or not
# * **threat_level:** Threat level from the victim
# * **flee:** Either victim fleed or not, if fleed then used vehicle
# * **body_camera:** Either the occurance is recorded using camera or not
# * **longitude:** Longitude of the place of occurance
# * **latitude:** Latitude of the place of occurance
# * **is_geocoding_exact:** Either the place of occurance is exactly available or not

# %%
us_df.tail()
# Out:
#         id                   name        date manner_of_death        armed  \
# 7724  7725                    NaN  2022-09-07            shot  screwdriver
# 7725  7726                    NaN  2022-09-07            shot          gun
# 7726  7727                    NaN  2022-09-07            shot        knife
# 7727  7728  Tyler Michael Gardner  2022-09-07            shot          gun
# 7728  7729  Reginald Lamont Grant  2022-09-07            shot          gun
#
#        age gender race               city state  signs_of_mental_illness  \
# 7724   NaN      M  NaN          Flagstaff    AZ                    False
# 7725   NaN      M    W        Springville    AL                    False
# 7726  61.0      M    B          St. Louis    MO                    False
# 7727  27.0      M  NaN  Washington County    TN                    False
# 7728  30.0      M  NaN           Columbus    GA                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# 7724        other         Foot        False   -111.584    35.224
# 7725       attack          Car        False    -86.472    33.775
# 7726        other  Not fleeing        False    -90.290    38.668
# 7727       attack        Other        False    -82.539    36.309
# 7728       attack         Foot        False        NaN       NaN
#
#       is_geocoding_exact
# 7724                True
# 7725                True
# 7726                True
# 7727                True
# 7728                True

# %%
us_df.shape
# Out:
# (7729, 17)

# %%
print(f"\nGlimpse Of The Dataset :")
us_df.head().style.set_properties(**{"background-color": "lightblue ","color":"#092434","border": "1.5px #ddab46"})
# Out:
# Glimpse Of The Dataset :
# <style type="text/css">
# #T_4768c_row0_col0, #T_4768c_row0_col1, #T_4768c_row0_col2, #T_4768c_row0_col3, #T_4768c_row0_col4, #T_4768c_row0_col5, #T_4768c_row0_col6, #T_4768c_row0_col7, #T_4768c_row0_col8, #T_4768c_row0_col9, #T_4768c_row0_col10, #T_4768c_row0_col11, #T_4768c_row0_col12, #T_4768c_row0_col13, #T_4768c_row1_col0, #T_4768c_row1_col1, #T_4768c_row1_col2, #T_4768c_row1_col3, #T_4768c_row1_col4, #T_4768c_row1_col5, #T_4768c_row1_col6, #T_4768c_row1_col7, #T_4768c_row1_col8, #T_4768c_row1_col9, #T_4768c_row1_col10, #T_4768c_row1_col11, #T_4768c_row1_col12, #T_4768c_row1_col13, #T_4768c_row2_col0, #T_4768c_row2_col1, #T_4768c_row2_col2, #T_4768c_row2_col3, #T_4768c_row2_col4, #T_4768c_row2_col5, #T_4768c_row2_col6, #T_4768c_row2_col7, #T_4768c_row2_col8, #T_4768c_row2_col9, #T_4768c_row2_col10, #T_4768c_row2_col11, #T_4768c_row2_col12, #T_4768c_row2_col13, #T_4768c_row3_col0, #T_4768c_row3_col1, #T_4768c_row3_col2, #T_4768c_row3_col3, #T_4768c_row3_col4, #T_4768c_row3_col5, #T_4768c_row3_col6, #T_4768c_row3_col7, #T_4768c_row3_col8, #T_4768c_row3_col9, #T_4768c_row3_col10, #T_4768c_row3_col11, #T_4768c_row3_col12, #T_4768c_row3_col13, #T_4768c_row4_col0, #T_4768c_row4_col1, #T_4768c_row4_col2, #T_4768c_row4_col3, #T_4768c_row4_col4, #T_4768c_row4_col5, #T_4768c_row4_col6, #T_4768c_row4_col7, #T_4768c_row4_col8, #T_4768c_row4_col9, #T_4768c_row4_col10, #T_4768c_row4_col11, #T_4768c_row4_col12, #T_4768c_row4_col13 {
#   background-color: lightblue;
#   color: #092434;
#   border: 1.5px #ddab46;
# }
# </style>
# <table id="T_4768c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4768c_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_4768c_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_4768c_level0_col2" class="col_heading level0 col2" >State</th>
#       <th id="T_4768c_level0_col3" class="col_heading level0 col3" >State Code</th>
#       <th id="T_4768c_level0_col4" class="col_heading level0 col4" >Name</th>
#       <th id="T_4768c_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_4768c_level0_col6" class="col_heading level0 col6" >Gender</th>
#       <th id="T_4768c_level0_col7" class="col_heading level0 col7" >Race</th>
#       <th id="T_4768c_level0_col8" class="col_heading level0 col8" >Mental Illness</th>
#       <th id="T_4768c_level0_col9" class="col_heading level0 col9" >Armed</th>
#       <th id="T_4768c_level0_col10" class="col_heading level0 col10" >Threat Level</th>
#       <th id="T_4768c_level0_col11" class="col_heading level0 col11" >Manner Of Death</th>
#       <th id="T_4768c_level0_col12" class="col_heading level0 col12" >Flee</th>
#       <th id="T_4768c_level0_col13" class="col_heading level0 col13" >Footage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4768c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4768c_row0_col0" class="data row0 col0" >2015</td>
#       <td id="T_4768c_row0_col1" class="data row0 col1" >Shelton</td>
#       <td id="T_4768c_row0_col2" class="data row0 col2" >WA</td>
#       <td id="T_4768c_row0_col3" class="data row0 col3" >WA</td>
#       <td id="T_4768c_row0_col4" class="data row0 col4" >Tim Elliot</td>
#       <td id="T_4768c_row0_col5" class="data row0 col5" >53.000000</td>
#       <td id="T_4768c_row0_col6" class="data row0 col6" >Male</td>
#       <td id="T_4768c_row0_col7" class="data row0 col7" >Asian</td>
#       <td id="T_4768c_row0_col8" class="data row0 col8" >Abnormal</td>
#       <td id="T_4768c_row0_col9" class="data row0 col9" >Gun</td>
#       <td id="T_4768c_row0_col10" class="data row0 col10" >Attack</td>
#       <td id="T_4768c_row0_col11" class="data row0 col11" >Shot</td>
#       <td id="T_4768c_row0_col12" class="data row0 col12" >Not Fleeing</td>
#       <td id="T_4768c_row0_col13" class="data row0 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_4768c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4768c_row1_col0" class="data row1 col0" >2015</td>
#       <td id="T_4768c_row1_col1" class="data row1 col1" >Aloha</td>
#       <td id="T_4768c_row1_col2" class="data row1 col2" >OR</td>
#       <td id="T_4768c_row1_col3" class="data row1 col3" >OR</td>
#       <td id="T_4768c_row1_col4" class="data row1 col4" >Lewis Lee Lembke</td>
#       <td id="T_4768c_row1_col5" class="data row1 col5" >47.000000</td>
#       <td id="T_4768c_row1_col6" class="data row1 col6" >Male</td>
#       <td id="T_4768c_row1_col7" class="data row1 col7" >White</td>
#       <td id="T_4768c_row1_col8" class="data row1 col8" >Normal</td>
#       <td id="T_4768c_row1_col9" class="data row1 col9" >Gun</td>
#       <td id="T_4768c_row1_col10" class="data row1 col10" >Attack</td>
#       <td id="T_4768c_row1_col11" class="data row1 col11" >Shot</td>
#       <td id="T_4768c_row1_col12" class="data row1 col12" >Not Fleeing</td>
#       <td id="T_4768c_row1_col13" class="data row1 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_4768c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4768c_row2_col0" class="data row2 col0" >2015</td>
#       <td id="T_4768c_row2_col1" class="data row2 col1" >Wichita</td>
#       <td id="T_4768c_row2_col2" class="data row2 col2" >KS</td>
#       <td id="T_4768c_row2_col3" class="data row2 col3" >KS</td>
#       <td id="T_4768c_row2_col4" class="data row2 col4" >John Paul Quintero</td>
#       <td id="T_4768c_row2_col5" class="data row2 col5" >23.000000</td>
#       <td id="T_4768c_row2_col6" class="data row2 col6" >Male</td>
#       <td id="T_4768c_row2_col7" class="data row2 col7" >Hispanic</td>
#       <td id="T_4768c_row2_col8" class="data row2 col8" >Normal</td>
#       <td id="T_4768c_row2_col9" class="data row2 col9" >Unarmed</td>
#       <td id="T_4768c_row2_col10" class="data row2 col10" >Not Attack</td>
#       <td id="T_4768c_row2_col11" class="data row2 col11" >Shot and Tasered</td>
#       <td id="T_4768c_row2_col12" class="data row2 col12" >Not Fleeing</td>
#       <td id="T_4768c_row2_col13" class="data row2 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_4768c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4768c_row3_col0" class="data row3 col0" >2015</td>
#       <td id="T_4768c_row3_col1" class="data row3 col1" >San Francisco</td>
#       <td id="T_4768c_row3_col2" class="data row3 col2" >CA</td>
#       <td id="T_4768c_row3_col3" class="data row3 col3" >CA</td>
#       <td id="T_4768c_row3_col4" class="data row3 col4" >Matthew Hoffman</td>
#       <td id="T_4768c_row3_col5" class="data row3 col5" >32.000000</td>
#       <td id="T_4768c_row3_col6" class="data row3 col6" >Male</td>
#       <td id="T_4768c_row3_col7" class="data row3 col7" >White</td>
#       <td id="T_4768c_row3_col8" class="data row3 col8" >Abnormal</td>
#       <td id="T_4768c_row3_col9" class="data row3 col9" >Toy Weapon</td>
#       <td id="T_4768c_row3_col10" class="data row3 col10" >Attack</td>
#       <td id="T_4768c_row3_col11" class="data row3 col11" >Shot</td>
#       <td id="T_4768c_row3_col12" class="data row3 col12" >Not Fleeing</td>
#       <td id="T_4768c_row3_col13" class="data row3 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_4768c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4768c_row4_col0" class="data row4 col0" >2015</td>
#       <td id="T_4768c_row4_col1" class="data row4 col1" >Evans</td>
#       <td id="T_4768c_row4_col2" class="data row4 col2" >CO</td>
#       <td id="T_4768c_row4_col3" class="data row4 col3" >CO</td>
#       <td id="T_4768c_row4_col4" class="data row4 col4" >Michael Rodriguez</td>
#       <td id="T_4768c_row4_col5" class="data row4 col5" >39.000000</td>
#       <td id="T_4768c_row4_col6" class="data row4 col6" >Male</td>
#       <td id="T_4768c_row4_col7" class="data row4 col7" >Hispanic</td>
#       <td id="T_4768c_row4_col8" class="data row4 col8" >Normal</td>
#       <td id="T_4768c_row4_col9" class="data row4 col9" >nail gun</td>
#       <td id="T_4768c_row4_col10" class="data row4 col10" >Attack</td>
#       <td

# %%
us_df.describe(include="object").T.style.set_properties(**{"background-color": "lightblue","color":"#452912","border": "1.5px #ddab46"})
# Out:
# <style type="text/css">
# #T_321fb_row0_col0, #T_321fb_row0_col1, #T_321fb_row0_col2, #T_321fb_row0_col3, #T_321fb_row1_col0, #T_321fb_row1_col1, #T_321fb_row1_col2, #T_321fb_row1_col3, #T_321fb_row2_col0, #T_321fb_row2_col1, #T_321fb_row2_col2, #T_321fb_row2_col3, #T_321fb_row3_col0, #T_321fb_row3_col1, #T_321fb_row3_col2, #T_321fb_row3_col3, #T_321fb_row4_col0, #T_321fb_row4_col1, #T_321fb_row4_col2, #T_321fb_row4_col3, #T_321fb_row5_col0, #T_321fb_row5_col1, #T_321fb_row5_col2, #T_321fb_row5_col3, #T_321fb_row6_col0, #T_321fb_row6_col1, #T_321fb_row6_col2, #T_321fb_row6_col3, #T_321fb_row7_col0, #T_321fb_row7_col1, #T_321fb_row7_col2, #T_321fb_row7_col3, #T_321fb_row8_col0, #T_321fb_row8_col1, #T_321fb_row8_col2, #T_321fb_row8_col3, #T_321fb_row9_col0, #T_321fb_row9_col1, #T_321fb_row9_col2, #T_321fb_row9_col3, #T_321fb_row10_col0, #T_321fb_row10_col1, #T_321fb_row10_col2, #T_321fb_row10_col3, #T_321fb_row11_col0, #T_321fb_row11_col1, #T_321fb_row11_col2, #T_321fb_row11_col3 {
#   background-color: lightblue;
#   color: #452912;
#   border: 1.5px #ddab46;
# }
# </style>
# <table id="T_321fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_321fb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_321fb_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_321fb_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_321fb_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_321fb_level0_row0" class="row_heading level0 row0" >City</th>
#       <td id="T_321fb_row0_col0" class="data row0 col0" >5070</td>
#       <td id="T_321fb_row0_col1" class="data row0 col1" >2309</td>
#       <td id="T_321fb_row0_col2" class="data row0 col2" >Los Angeles</td>
#       <td id="T_321fb_row0_col3" class="data row0 col3" >78</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row1" class="row_heading level0 row1" >State</th>
#       <td id="T_321fb_row1_col0" class="data row1 col0" >5070</td>
#       <td id="T_321fb_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_321fb_row1_col2" class="data row1 col2" >CA</td>
#       <td id="T_321fb_row1_col3" class="data row1 col3" >739</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row2" class="row_heading level0 row2" >State Code</th>
#       <td id="T_321fb_row2_col0" class="data row2 col0" >5070</td>
#       <td id="T_321fb_row2_col1" class="data row2 col1" >51</td>
#       <td id="T_321fb_row2_col2" class="data row2 col2" >CA</td>
#       <td id="T_321fb_row2_col3" class="data row2 col3" >739</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row3" class="row_heading level0 row3" >Name</th>
#       <td id="T_321fb_row3_col0" class="data row3 col0" >5070</td>
#       <td id="T_321fb_row3_col1" class="data row3 col1" >5061</td>
#       <td id="T_321fb_row3_col2" class="data row3 col2" >David Willoughby</td>
#       <td id="T_321fb_row3_col3" class="data row3 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row4" class="row_heading level0 row4" >Gender</th>
#       <td id="T_321fb_row4_col0" class="data row4 col0" >5070</td>
#       <td id="T_321fb_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_321fb_row4_col2" class="data row4 col2" >Male</td>
#       <td id="T_321fb_row4_col3" class="data row4 col3" >4815</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row5" class="row_heading level0 row5" >Race</th>
#       <td id="T_321fb_row5_col0" class="data row5 col0" >5070</td>
#       <td id="T_321fb_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_321fb_row5_col2" class="data row5 col2" >White</td>
#       <td id="T_321fb_row5_col3" class="data row5 col3" >2583</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row6" class="row_heading level0 row6" >Mental Illness</th>
#       <td id="T_321fb_row6_col0" class="data row6 col0" >5070</td>
#       <td id="T_321fb_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_321fb_row6_col2" class="data row6 col2" >Normal</td>
#       <td id="T_321fb_row6_col3" class="data row6 col3" >3849</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row7" class="row_heading level0 row7" >Armed</th>
#       <td id="T_321fb_row7_col0" class="data row7 col0" >5070</td>
#       <td id="T_321fb_row7_col1" class="data row7 col1" >94</td>
#       <td id="T_321fb_row7_col2" class="data row7 col2" >Gun</td>
#       <td id="T_321fb_row7_col3" class="data row7 col3" >2987</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row8" class="row_heading level0 row8" >Threat Level</th>
#       <td id="T_321fb_row8_col0" class="data row8 col0" >5070</td>
#       <td id="T_321fb_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_321fb_row8_col2" class="data row8 col2" >Attack</td>
#       <td id="T_321fb_row8_col3" class="data row8 col3" >3334</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row9" class="row_heading level0 row9" >Manner Of Death</th>
#       <td id="T_321fb_row9_col0" class="data row9 col0" >5070</td>
#       <td id="T_321fb_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_321fb_row9_col2" class="data row9 col2" >Shot</td>
#       <td id="T_321fb_row9_col3" class="data row9 col3" >4799</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row10" class="row_heading level0 row10" >Flee</th>
#       <td id="T_321fb_row10_col0" class="data row10 col0" >5070</td>
#       <td id="T_321fb_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_321fb_row10_col2" class="data row10 col2" >Not Fleeing</td>
#       <td id="T_321fb_row10_col3" class="data row10 col3" >3355</td>
#     </tr>
#     <tr>
#       <th id="T_321fb_level0_row11" class="row_heading level0 row11" >Footage</th>
#       <td id="T_321fb_row11_col0" class="data row11 col0" >5070</td>
#       <td id="T_321fb_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_321fb_row11_col2" class="data row11 col2" >Not Available</td>
#       <td id="T_321fb_row11_col3" class="data row11 col3" >4334</td>
#     </tr>
#   </tbody>
# </table>

# %%
us_df.describe(include="object").T.style.set_properties(**{"background-color": "lightblue","color":"#452912","border": "1.5px #ddab46"})
# Out:
# <style type="text/css">
# #T_606df_row0_col0, #T_606df_row0_col1, #T_606df_row0_col2, #T_606df_row0_col3, #T_606df_row1_col0, #T_606df_row1_col1, #T_606df_row1_col2, #T_606df_row1_col3, #T_606df_row2_col0, #T_606df_row2_col1, #T_606df_row2_col2, #T_606df_row2_col3, #T_606df_row3_col0, #T_606df_row3_col1, #T_606df_row3_col2, #T_606df_row3_col3, #T_606df_row4_col0, #T_606df_row4_col1, #T_606df_row4_col2, #T_606df_row4_col3, #T_606df_row5_col0, #T_606df_row5_col1, #T_606df_row5_col2, #T_606df_row5_col3, #T_606df_row6_col0, #T_606df_row6_col1, #T_606df_row6_col2, #T_606df_row6_col3, #T_606df_row7_col0, #T_606df_row7_col1, #T_606df_row7_col2, #T_606df_row7_col3, #T_606df_row8_col0, #T_606df_row8_col1, #T_606df_row8_col2, #T_606df_row8_col3, #T_606df_row9_col0, #T_606df_row9_col1, #T_606df_row9_col2, #T_606df_row9_col3, #T_606df_row10_col0, #T_606df_row10_col1, #T_606df_row10_col2, #T_606df_row10_col3, #T_606df_row11_col0, #T_606df_row11_col1, #T_606df_row11_col2, #T_606df_row11_col3 {
#   background-color: lightblue;
#   color: #452912;
#   border: 1.5px #ddab46;
# }
# </style>
# <table id="T_606df" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_606df_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_606df_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_606df_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_606df_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_606df_level0_row0" class="row_heading level0 row0" >City</th>
#       <td id="T_606df_row0_col0" class="data row0 col0" >5070</td>
#       <td id="T_606df_row0_col1" class="data row0 col1" >2309</td>
#       <td id="T_606df_row0_col2" class="data row0 col2" >Los Angeles</td>
#       <td id="T_606df_row0_col3" class="data row0 col3" >78</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row1" class="row_heading level0 row1" >State</th>
#       <td id="T_606df_row1_col0" class="data row1 col0" >5070</td>
#       <td id="T_606df_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_606df_row1_col2" class="data row1 col2" >CA</td>
#       <td id="T_606df_row1_col3" class="data row1 col3" >739</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row2" class="row_heading level0 row2" >State Code</th>
#       <td id="T_606df_row2_col0" class="data row2 col0" >5070</td>
#       <td id="T_606df_row2_col1" class="data row2 col1" >51</td>
#       <td id="T_606df_row2_col2" class="data row2 col2" >CA</td>
#       <td id="T_606df_row2_col3" class="data row2 col3" >739</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row3" class="row_heading level0 row3" >Name</th>
#       <td id="T_606df_row3_col0" class="data row3 col0" >5070</td>
#       <td id="T_606df_row3_col1" class="data row3 col1" >5061</td>
#       <td id="T_606df_row3_col2" class="data row3 col2" >David Willoughby</td>
#       <td id="T_606df_row3_col3" class="data row3 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row4" class="row_heading level0 row4" >Gender</th>
#       <td id="T_606df_row4_col0" class="data row4 col0" >5070</td>
#       <td id="T_606df_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_606df_row4_col2" class="data row4 col2" >Male</td>
#       <td id="T_606df_row4_col3" class="data row4 col3" >4815</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row5" class="row_heading level0 row5" >Race</th>
#       <td id="T_606df_row5_col0" class="data row5 col0" >5070</td>
#       <td id="T_606df_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_606df_row5_col2" class="data row5 col2" >White</td>
#       <td id="T_606df_row5_col3" class="data row5 col3" >2583</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row6" class="row_heading level0 row6" >Mental Illness</th>
#       <td id="T_606df_row6_col0" class="data row6 col0" >5070</td>
#       <td id="T_606df_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_606df_row6_col2" class="data row6 col2" >Normal</td>
#       <td id="T_606df_row6_col3" class="data row6 col3" >3849</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row7" class="row_heading level0 row7" >Armed</th>
#       <td id="T_606df_row7_col0" class="data row7 col0" >5070</td>
#       <td id="T_606df_row7_col1" class="data row7 col1" >94</td>
#       <td id="T_606df_row7_col2" class="data row7 col2" >Gun</td>
#       <td id="T_606df_row7_col3" class="data row7 col3" >2987</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row8" class="row_heading level0 row8" >Threat Level</th>
#       <td id="T_606df_row8_col0" class="data row8 col0" >5070</td>
#       <td id="T_606df_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_606df_row8_col2" class="data row8 col2" >Attack</td>
#       <td id="T_606df_row8_col3" class="data row8 col3" >3334</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row9" class="row_heading level0 row9" >Manner Of Death</th>
#       <td id="T_606df_row9_col0" class="data row9 col0" >5070</td>
#       <td id="T_606df_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_606df_row9_col2" class="data row9 col2" >Shot</td>
#       <td id="T_606df_row9_col3" class="data row9 col3" >4799</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row10" class="row_heading level0 row10" >Flee</th>
#       <td id="T_606df_row10_col0" class="data row10 col0" >5070</td>
#       <td id="T_606df_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_606df_row10_col2" class="data row10 col2" >Not Fleeing</td>
#       <td id="T_606df_row10_col3" class="data row10 col3" >3355</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row11" class="row_heading level0 row11" >Footage</th>
#       <td id="T_606df_row11_col0" class="data row11 col0" >5070</td>
#       <td id="T_606df_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_606df_row11_col2" class="data row11 col2" >Not Available</td>
#       <td id="T_606df_row11_col3" class="data row11 col3" >4334</td>
#     </tr>
#   </tbody>
# </table>

# %%
us_df.duplicated().sum()
# Out:
# 0

# %%
us_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7729 entries, 0 to 7728
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       7729 non-null   int64
#  1   name                     7312 non-null   object
#  2   date                     7729 non-null   object
#  3   manner_of_death          7729 non-null   object
#  4   armed                    7520 non-null   object
#  5   age                      7247 non-null   float64
#  6   gender                   7709 non-null   object
#  7   race                     6269 non-null   object
#  8   city                     7729 non-null   object
#  9   state                    7729 non-null   object
#  10  signs_of_mental_illness  7729 non-null   bool
#  11  threat_level             7729 non-null   object
#  12  flee                     6854 non-null   object
#  13  body_camera              7729 non-null   bool
#  14  longitude                6892 non-null   float64
#  15  latitude                 6892 non-null   float64
#  16  is_geocoding_exact       7729 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(10)
# memory usage: 868.1+ KB

# %%
us_df.dtypes
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# longitude                  float64
# latitude                   float64
# is_geocoding_exact            bool
# dtype: object

# %%
us_df.corr()
# Out:
# <ipython-input-12-b0f191c1ad15>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   us_df.corr()
#                                id       age  signs_of_mental_illness  \
# id                       1.000000  0.026014                -0.108246
# age                      0.026014  1.000000                 0.098243
# signs_of_mental_illness -0.108246  0.098243                 1.000000
# body_camera              0.093273 -0.052729                 0.045474
# longitude                0.020586  0.059376                 0.025324
# latitude                 0.007124 -0.016994                 0.029995
# is_geocoding_exact      -0.017828 -0.001531                 0.011944
#
#                          body_camera  longitude  latitude  is_geocoding_exact
# id                          0.093273   0.020586  0.007124           -0.017828
# age                        -0.052729   0.059376 -0.016994           -0.001531
# signs_of_mental_illness     0.045474   0.025324  0.029995            0.011944
# body_camera                 1.000000  -0.047607  0.010161            0.004413
# longitude                  -0.047607   1.000000 -0.115223           -0.004371
# latitude                    0.010161  -0.115223  1.000000           -0.011820
# is_geocoding_exact          0.004413  -0.004371 -0.011820            1.000000

# %%
us_df.isnull()
# Out:
#          id   name   date  manner_of_death  armed    age  gender   race  \
# 0     False  False  False            False  False  False   False  False
# 1     False  False  False            False  False  False   False  False
# 2     False  False  False            False  False  False   False  False
# 3     False  False  False            False  False  False   False  False
# 4     False  False  False            False  False  False   False  False
# ...     ...    ...    ...              ...    ...    ...     ...    ...
# 7724  False   True  False            False  False   True   False   True
# 7725  False   True  False            False  False   True   False  False
# 7726  False   True  False            False  False  False   False  False
# 7727  False  False  False            False  False  False   False   True
# 7728  False  False  False            False  False  False   False   True
#
#        city  state  signs_of_mental_illness  threat_level   flee  body_camera  \
# 0     False  False                    False         False  False        False
# 1     False  False                    False         False  False        False
# 2     False  False                    False         False  False        False
# 3     False  False                    False         False  False        False
# 4     False  False                    False         False  False        False
# ...     ...    ...                      ...           ...    ...          ...
# 7724  False  False                    False         False  False        False
# 7725  False  False                    False         False  False        False
# 7726  False  False                    False         False  False        False
# 7727  False  False                    False         False  False        False
# 7728  False  False                    False         False  False        False
#
#       longitude  latitude  is_geocoding_exact
# 0         False     False               False
# 1         False     False               False
# 2         False     False               False
# 3         False     False               False
# 4         False     False               False
# ...         ...       ...                 ...
# 7724      False     False               False
# 7725      False     False               False
# 7726      False     False               False
# 7727      False     False               False
# 7728       True      True               False
#
# [7729 rows x 17 columns]

# %%
print(f"Null values of the Dataset :")
us_df.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#lightblue","color":"#452912","border": "1.5px #ddab46"})
# Out:
# Null values of the Dataset :
# <style type="text/css">
# #T_bb673_row0_col0, #T_bb673_row0_col1, #T_bb673_row0_col2, #T_bb673_row0_col3, #T_bb673_row0_col4, #T_bb673_row0_col5, #T_bb673_row0_col6, #T_bb673_row0_col7, #T_bb673_row0_col8, #T_bb673_row0_col9, #T_bb673_row0_col10, #T_bb673_row0_col11, #T_bb673_row0_col12, #T_bb673_row0_col13, #T_bb673_row0_col14, #T_bb673_row0_col15, #T_bb673_row0_col16 {
#   background-color: #ddab46;
#   color: #452912;
#   border: 1.5px #ddab46;
# }
# </style>
# <table id="T_bb673" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb673_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_bb673_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_bb673_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_bb673_level0_col3" class="col_heading level0 col3" >manner_of_death</th>
#       <th id="T_bb673_level0_col4" class="col_heading level0 col4" >armed</th>
#       <th id="T_bb673_level0_col5" class="col_heading level0 col5" >age</th>
#       <th id="T_bb673_level0_col6" class="col_heading level0 col6" >gender</th>
#       <th id="T_bb673_level0_col7" class="col_heading level0 col7" >race</th>
#       <th id="T_bb673_level0_col8" class="col_heading level0 col8" >city</th>
#       <th id="T_bb673_level0_col9" class="col_heading level0 col9" >state</th>
#       <th id="T_bb673_level0_col10" class="col_heading level0 col10" >signs_of_mental_illness</th>
#       <th id="T_bb673_level0_col11" class="col_heading level0 col11" >threat_level</th>
#       <th id="T_bb673_level0_col12" class="col_heading level0 col12" >flee</th>
#       <th id="T_bb673_level0_col13" class="col_heading level0 col13" >body_camera</th>
#       <th id="T_bb673_level0_col14" class="col_heading level0 col14" >longitude</th>
#       <th id="T_bb673_level0_col15" class="col_heading level0 col15" >latitude</th>
#       <th id="T_bb673_level0_col16" class="col_heading level0 col16" >is_geocoding_exact</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb673_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb673_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_bb673_row0_col1" class="data row0 col1" >417</td>
#       <td id="T_bb673_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_bb673_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bb673_row0_col4" class="data row0 col4" >209</td>
#       <td id="T_bb673_row0_col5" class="data row0 col5" >482</td>
#       <td id="T_bb673_row0_col6" class="data row0 col6" >20</td>
#       <td id="T_bb673_row0_col7" class="data row0 col7" >1460</td>
#       <td id="T_bb673_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_bb673_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_bb673_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_bb673_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_bb673_row0_col12" class="data row0 col12" >875</td>
#       <td id="T_bb673_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_bb673_row0_col14" class="data row0 col14" >837</td>
#       <td id="T_bb673_row0_col15" class="data row0 col15" >837</td>
#       <td id="T_bb673_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Check for null values.
for col in us_df.columns:
  null_rate = us_df[col].isnull().sum() / len(us_df) * 100
  if null_rate > 0:
    print(f'Percentage of null values in {col} : {null_rate}%')
# Out:
# Percentage of null values in name : 5.3952645879156425%
# Percentage of null values in armed : 2.7041014361495663%
# Percentage of null values in age : 6.236253072842541%
# Percentage of null values in gender : 0.25876568766981495%
# Percentage of null values in race : 18.889895199896493%
# Percentage of null values in flee : 11.320998835554406%
# Percentage of null values in longitude : 10.829344028981756%
# Percentage of null values in latitude : 10.829344028981756%

# %%
null_percent = us_df.isnull().sum()/us_df.shape[0]*100
null_percent.plot(kind='bar', color='lightblue')
plt.title("Percentage of null values in each Column")
plt.show()

# %%
us_df.dropna(axis = 0, inplace = True)
print(f"After dropping null values, the shape of the Dataset is {us_df.shape}")
print(f"After dropping null values, null values of the Dataset :")
us_df.isna().sum().to_frame().T.style.set_properties(**{"background-color": "lightblue","color":"#452912","border": "1.5px #ddab46"})
# Out:
# After dropping null values, the shape of the Dataset is (5070, 14)
# After dropping null values, null values of the Dataset :
# <style type="text/css">
# #T_40bb7_row0_col0, #T_40bb7_row0_col1, #T_40bb7_row0_col2, #T_40bb7_row0_col3, #T_40bb7_row0_col4, #T_40bb7_row0_col5, #T_40bb7_row0_col6, #T_40bb7_row0_col7, #T_40bb7_row0_col8, #T_40bb7_row0_col9, #T_40bb7_row0_col10, #T_40bb7_row0_col11, #T_40bb7_row0_col12, #T_40bb7_row0_col13 {
#   background-color: lightblue;
#   color: #452912;
#   border: 1.5px #ddab46;
# }
# </style>
# <table id="T_40bb7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40bb7_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_40bb7_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_40bb7_level0_col2" class="col_heading level0 col2" >State</th>
#       <th id="T_40bb7_level0_col3" class="col_heading level0 col3" >State Code</th>
#       <th id="T_40bb7_level0_col4" class="col_heading level0 col4" >Name</th>
#       <th id="T_40bb7_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_40bb7_level0_col6" class="col_heading level0 col6" >Gender</th>
#       <th id="T_40bb7_level0_col7" class="col_heading level0 col7" >Race</th>
#       <th id="T_40bb7_level0_col8" class="col_heading level0 col8" >Mental Illness</th>
#       <th id="T_40bb7_level0_col9" class="col_heading level0 col9" >Armed</th>
#       <th id="T_40bb7_level0_col10" class="col_heading level0 col10" >Threat Level</th>
#       <th id="T_40bb7_level0_col11" class="col_heading level0 col11" >Manner Of Death</th>
#       <th id="T_40bb7_level0_col12" class="col_heading level0 col12" >Flee</th>
#       <th id="T_40bb7_level0_col13" class="col_heading level0 col13" >Footage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40bb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40bb7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_40bb7_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_40bb7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_40bb7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_40bb7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_40bb7_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_40bb7_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_40bb7_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_40bb7_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_40bb7_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_40bb7_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_40bb7_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_40bb7_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_40bb7_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Data Preprocessing**

# %%
states = {
        'AL': 'Alabama',
        'AK': 'Alaska',
        'AZ': 'Arizona',
        'AR': 'Arkansas',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'IA': 'Iowa',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'ME': 'Maine',
        'MD': 'Maryland',
        'MA': 'Massachusetts',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MS': 'Mississippi',
        'MO': 'Missouri',
        'MT': 'Montana',
        'NE': 'Nebraska',
        'NV': 'Nevada',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NY': 'New York',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VT': 'Vermont',
        'VA': 'Virginia',
        'WA': 'Washington',
        'WV': 'West Virginia',
        'WI': 'Wisconsin',
        'WY': 'Wyoming',
        'DC': 'District of Columbia',
        'MP': 'Northern Mariana Islands',
        'PW': 'Palau',
        'PR': 'Puerto Rico',
        'VI': 'Virgin Islands',
        'AA': 'Armed Forces Americas (Except Canada)',
        'AE': 'Armed Forces Africa/Canada/Europe/Middle East',
        'AP': 'Armed Forces Pacific'
        }

# %%
us_df["State"] = us_df["state"].replace('states')
us_df['date'] = pd.to_datetime(us_df['date'])
us_df['Year'] = us_df['date'].dt.year
us_df['Month'] = us_df['date'].dt.month
us_df['Day'] = us_df['date'].dt.day
us_df["manner_of_death"].replace({"shot":"Shot", "shot and Tasered":"Shot and Tasered"}, inplace = True)
us_df["armed"].replace({"gun":"Gun", "knife":"Knife", "unarmed":"Unarmed", "undetermined":"Undetermined", "vehicle":"Vehicle", "toy weapon":"Toy Weapon", "unknown weapon":"Unknown Weapon", "machete":"Machete"}, inplace = True)
us_df["gender"].replace({"M":"Male", "F":"Female"}, inplace = True)

# %%
us_df["signs_of_mental_illness"].replace({True:"Abnormal", False:"Normal"}, inplace = True)
us_df["body_camera"].replace({True:"Available", False:"Not Available"}, inplace = True)
us_df["race"].replace({"W":"White", "B":"Black", "H":"Hispanic", "A":"Asian", "N":"Native", "O":"Other"}, inplace = True)
us_df["threat_level"].replace({"attack":"Attack", "other":"Not Attack", "undetermined":"Unknown"}, inplace = True)
us_df["flee"].replace({"Not fleeing":"Not Fleeing", "Other":"Unknown"}, inplace = True)
us_df.rename(columns={"name": "Name","date": "Date","manner_of_death": "Manner Of Death","armed":"Armed","age":"Age","gender":"Gender","race":"Race","city":"City","state": "State Code","signs_of_mental_illness":"Mental Illness","threat_level":"Threat Level","flee":"Flee","body_camera":"Footage"}, inplace = True)
us_df = us_df[["Year","City","State", "State Code","Name","Age","Gender","Race","Mental Illness","Armed","Threat Level","Manner Of Death","Flee","Footage"]]

# %%
#Drop extra columns
us_df.drop(['id', 'longitude', 'latitude', 'is_geocoding_exact'], inplace = True , axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d617c2792851> in <cell line: 2>()
#       1 #Drop extra columns
# ----> 2 us_df.drop(['id', 'longitude', 'latitude', 'is_geocoding_exact'], inplace = True , axis =1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['id', 'longitude', 'latitude', 'is_geocoding_exact'] not found in axis"

# %%
print(" Glimpse of the final dataset :")
us_df.head().style.set_properties(**{"background-color": "lightblue", "color": "#452912", "border": "1.5px #ddab46"})
# Out:
#  Glimpse of the final dataset :
# <style type="text/css">
# #T_cdabf_row0_col0, #T_cdabf_row0_col1, #T_cdabf_row0_col2, #T_cdabf_row0_col3, #T_cdabf_row0_col4, #T_cdabf_row0_col5, #T_cdabf_row0_col6, #T_cdabf_row0_col7, #T_cdabf_row0_col8, #T_cdabf_row0_col9, #T_cdabf_row0_col10, #T_cdabf_row0_col11, #T_cdabf_row0_col12, #T_cdabf_row0_col13, #T_cdabf_row1_col0, #T_cdabf_row1_col1, #T_cdabf_row1_col2, #T_cdabf_row1_col3, #T_cdabf_row1_col4, #T_cdabf_row1_col5, #T_cdabf_row1_col6, #T_cdabf_row1_col7, #T_cdabf_row1_col8, #T_cdabf_row1_col9, #T_cdabf_row1_col10, #T_cdabf_row1_col11, #T_cdabf_row1_col12, #T_cdabf_row1_col13, #T_cdabf_row2_col0, #T_cdabf_row2_col1, #T_cdabf_row2_col2, #T_cdabf_row2_col3, #T_cdabf_row2_col4, #T_cdabf_row2_col5, #T_cdabf_row2_col6, #T_cdabf_row2_col7, #T_cdabf_row2_col8, #T_cdabf_row2_col9, #T_cdabf_row2_col10, #T_cdabf_row2_col11, #T_cdabf_row2_col12, #T_cdabf_row2_col13, #T_cdabf_row3_col0, #T_cdabf_row3_col1, #T_cdabf_row3_col2, #T_cdabf_row3_col3, #T_cdabf_row3_col4, #T_cdabf_row3_col5, #T_cdabf_row3_col6, #T_cdabf_row3_col7, #T_cdabf_row3_col8, #T_cdabf_row3_col9, #T_cdabf_row3_col10, #T_cdabf_row3_col11, #T_cdabf_row3_col12, #T_cdabf_row3_col13, #T_cdabf_row4_col0, #T_cdabf_row4_col1, #T_cdabf_row4_col2, #T_cdabf_row4_col3, #T_cdabf_row4_col4, #T_cdabf_row4_col5, #T_cdabf_row4_col6, #T_cdabf_row4_col7, #T_cdabf_row4_col8, #T_cdabf_row4_col9, #T_cdabf_row4_col10, #T_cdabf_row4_col11, #T_cdabf_row4_col12, #T_cdabf_row4_col13 {
#   background-color: lightblue;
#   color: #452912;
#   border: 1.5px #ddab46;
# }
# </style>
# <table id="T_cdabf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdabf_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_cdabf_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_cdabf_level0_col2" class="col_heading level0 col2" >State</th>
#       <th id="T_cdabf_level0_col3" class="col_heading level0 col3" >State Code</th>
#       <th id="T_cdabf_level0_col4" class="col_heading level0 col4" >Name</th>
#       <th id="T_cdabf_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_cdabf_level0_col6" class="col_heading level0 col6" >Gender</th>
#       <th id="T_cdabf_level0_col7" class="col_heading level0 col7" >Race</th>
#       <th id="T_cdabf_level0_col8" class="col_heading level0 col8" >Mental Illness</th>
#       <th id="T_cdabf_level0_col9" class="col_heading level0 col9" >Armed</th>
#       <th id="T_cdabf_level0_col10" class="col_heading level0 col10" >Threat Level</th>
#       <th id="T_cdabf_level0_col11" class="col_heading level0 col11" >Manner Of Death</th>
#       <th id="T_cdabf_level0_col12" class="col_heading level0 col12" >Flee</th>
#       <th id="T_cdabf_level0_col13" class="col_heading level0 col13" >Footage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdabf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdabf_row0_col0" class="data row0 col0" >2015</td>
#       <td id="T_cdabf_row0_col1" class="data row0 col1" >Shelton</td>
#       <td id="T_cdabf_row0_col2" class="data row0 col2" >WA</td>
#       <td id="T_cdabf_row0_col3" class="data row0 col3" >WA</td>
#       <td id="T_cdabf_row0_col4" class="data row0 col4" >Tim Elliot</td>
#       <td id="T_cdabf_row0_col5" class="data row0 col5" >53.000000</td>
#       <td id="T_cdabf_row0_col6" class="data row0 col6" >Male</td>
#       <td id="T_cdabf_row0_col7" class="data row0 col7" >Asian</td>
#       <td id="T_cdabf_row0_col8" class="data row0 col8" >Abnormal</td>
#       <td id="T_cdabf_row0_col9" class="data row0 col9" >Gun</td>
#       <td id="T_cdabf_row0_col10" class="data row0 col10" >Attack</td>
#       <td id="T_cdabf_row0_col11" class="data row0 col11" >Shot</td>
#       <td id="T_cdabf_row0_col12" class="data row0 col12" >Not Fleeing</td>
#       <td id="T_cdabf_row0_col13" class="data row0 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_cdabf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdabf_row1_col0" class="data row1 col0" >2015</td>
#       <td id="T_cdabf_row1_col1" class="data row1 col1" >Aloha</td>
#       <td id="T_cdabf_row1_col2" class="data row1 col2" >OR</td>
#       <td id="T_cdabf_row1_col3" class="data row1 col3" >OR</td>
#       <td id="T_cdabf_row1_col4" class="data row1 col4" >Lewis Lee Lembke</td>
#       <td id="T_cdabf_row1_col5" class="data row1 col5" >47.000000</td>
#       <td id="T_cdabf_row1_col6" class="data row1 col6" >Male</td>
#       <td id="T_cdabf_row1_col7" class="data row1 col7" >White</td>
#       <td id="T_cdabf_row1_col8" class="data row1 col8" >Normal</td>
#       <td id="T_cdabf_row1_col9" class="data row1 col9" >Gun</td>
#       <td id="T_cdabf_row1_col10" class="data row1 col10" >Attack</td>
#       <td id="T_cdabf_row1_col11" class="data row1 col11" >Shot</td>
#       <td id="T_cdabf_row1_col12" class="data row1 col12" >Not Fleeing</td>
#       <td id="T_cdabf_row1_col13" class="data row1 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_cdabf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdabf_row2_col0" class="data row2 col0" >2015</td>
#       <td id="T_cdabf_row2_col1" class="data row2 col1" >Wichita</td>
#       <td id="T_cdabf_row2_col2" class="data row2 col2" >KS</td>
#       <td id="T_cdabf_row2_col3" class="data row2 col3" >KS</td>
#       <td id="T_cdabf_row2_col4" class="data row2 col4" >John Paul Quintero</td>
#       <td id="T_cdabf_row2_col5" class="data row2 col5" >23.000000</td>
#       <td id="T_cdabf_row2_col6" class="data row2 col6" >Male</td>
#       <td id="T_cdabf_row2_col7" class="data row2 col7" >Hispanic</td>
#       <td id="T_cdabf_row2_col8" class="data row2 col8" >Normal</td>
#       <td id="T_cdabf_row2_col9" class="data row2 col9" >Unarmed</td>
#       <td id="T_cdabf_row2_col10" class="data row2 col10" >Not Attack</td>
#       <td id="T_cdabf_row2_col11" class="data row2 col11" >Shot and Tasered</td>
#       <td id="T_cdabf_row2_col12" class="data row2 col12" >Not Fleeing</td>
#       <td id="T_cdabf_row2_col13" class="data row2 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_cdabf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cdabf_row3_col0" class="data row3 col0" >2015</td>
#       <td id="T_cdabf_row3_col1" class="data row3 col1" >San Francisco</td>
#       <td id="T_cdabf_row3_col2" class="data row3 col2" >CA</td>
#       <td id="T_cdabf_row3_col3" class="data row3 col3" >CA</td>
#       <td id="T_cdabf_row3_col4" class="data row3 col4" >Matthew Hoffman</td>
#       <td id="T_cdabf_row3_col5" class="data row3 col5" >32.000000</td>
#       <td id="T_cdabf_row3_col6" class="data row3 col6" >Male</td>
#       <td id="T_cdabf_row3_col7" class="data row3 col7" >White</td>
#       <td id="T_cdabf_row3_col8" class="data row3 col8" >Abnormal</td>
#       <td id="T_cdabf_row3_col9" class="data row3 col9" >Toy Weapon</td>
#       <td id="T_cdabf_row3_col10" class="data row3 col10" >Attack</td>
#       <td id="T_cdabf_row3_col11" class="data row3 col11" >Shot</td>
#       <td id="T_cdabf_row3_col12" class="data row3 col12" >Not Fleeing</td>
#       <td id="T_cdabf_row3_col13" class="data row3 col13" >Not Available</td>
#     </tr>
#     <tr>
#       <th id="T_cdabf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cdabf_row4_col0" class="data row4 col0" >2015</td>
#       <td id="T_cdabf_row4_col1" class="data row4 col1" >Evans</td>
#       <td id="T_cdabf_row4_col2" class="data row4 col2" >CO</td>
#       <td id="T_cdabf_row4_col3" class="data row4 col3" >CO</td>
#       <td id="T_cdabf_row4_col4" class="data row4 col4" >Michael Rodriguez</td>
#       <td id="T_cdabf_row4_col5" class="data row4 col5" >39.000000</td>
#       <td id="T_cdabf_row4_col6" class="data row4 col6" >Male</td>
#       <td id="T_cdabf_row4_col7" class="data row4 col7" >Hispanic</td>
#       <td id="T_cdabf_row4_col8" class="data row4 col8" >Normal</td>
#       <td id="T_cdabf_row4_col9" class="data row4 col9" >nail gun</td>
#       <td id="T_cdabf_row4_col10" class="data row4 col10" >Attack</td>
#       <td
