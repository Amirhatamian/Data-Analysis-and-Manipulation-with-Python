# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhatamian/PY/blob/main/Social%20Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
us_df = pd.read_csv('US Police shootings in from 2015-22.csv')

# %%
us_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   1          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   2    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   3  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   4     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   5   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
us_df.tail()
# Out:
#         id                   name        date manner_of_death        armed  \
# 7724  7725                    NaN  2022-09-07            shot  screwdriver
# 7725  7726                    NaN  2022-09-07            shot          gun
# 7726  7727                    NaN  2022-09-07            shot        knife
# 7727  7728  Tyler Michael Gardner  2022-09-07            shot          gun
# 7728  7729  Reginald Lamont Grant  2022-09-07            shot          gun
#
#        age gender race               city state  signs_of_mental_illness  \
# 7724   NaN      M  NaN          Flagstaff    AZ                    False
# 7725   NaN      M    W        Springville    AL                    False
# 7726  61.0      M    B          St. Louis    MO                    False
# 7727  27.0      M  NaN  Washington County    TN                    False
# 7728  30.0      M  NaN           Columbus    GA                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# ...

# %%
us_df.shape
# Out:
# (7729, 17)

# %%
us_df.duplicated().sum()
# Out:
# 0

# %%
us_df. describe()
# Out:
#                 id          age    longitude     latitude
# count  7729.000000  7247.000000  6892.000000  6892.000000
# mean   3865.000000    37.178971   -97.059875    36.682999
# std    2231.314448    12.966191    16.595557     5.402749
# min       1.000000     2.000000  -160.007000    19.498000
# 25%    1933.000000    27.000000  -112.039000    33.480000
# 50%    3865.000000    35.000000   -94.226000    36.104500
# 75%    5797.000000    45.000000   -83.073250    40.032250
# max    7729.000000    92.000000   -67.867000    71.301000

# %%
us_df.info()

# %%
us_df.dtypes
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# longitude                  float64
# latitude                   float64
# is_geocoding_exact            bool
# dtype: object

# %%
us_df.corr()
# Out:
# <ipython-input-14-b0f191c1ad15>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   us_df.corr()
#                                id       age  signs_of_mental_illness  \
# id                       1.000000  0.026014                -0.108246
# age                      0.026014  1.000000                 0.098243
# signs_of_mental_illness -0.108246  0.098243                 1.000000
# body_camera              0.093273 -0.052729                 0.045474
# longitude                0.020586  0.059376                 0.025324
# latitude                 0.007124 -0.016994                 0.029995
# is_geocoding_exact      -0.017828 -0.001531                 0.011944
#
#                          body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
us_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   1          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   2    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   3  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   4     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   5   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
us_df.isnull()
# Out:
#          id   name   date  manner_of_death  armed    age  gender   race  \
# 0     False  False  False            False  False  False   False  False
# 1     False  False  False            False  False  False   False  False
# 2     False  False  False            False  False  False   False  False
# 3     False  False  False            False  False  False   False  False
# 4     False  False  False            False  False  False   False  False
# ...     ...    ...    ...              ...    ...    ...     ...    ...
# 7724  False   True  False            False  False   True   False   True
# 7725  False   True  False            False  False   True   False  False
# 7726  False   True  False            False  False  False   False  False
# 7727  False  False  False            False  False  False   False   True
# 7728  False  False  False            False  False  False   False   True
#
#        city  state  signs_of_mental_illness  threat_level   flee  body_camera  \
# ...

# %%
us_df.isnull().sum()
# Out:
# id                            0
# name                        417
# date                          0
# manner_of_death               0
# armed                       209
# age                         482
# gender                       20
# race                       1460
# city                          0
# state                         0
# signs_of_mental_illness       0
# threat_level                  0
# flee                        875
# body_camera                   0
# longitude                   837
# latitude                    837
# is_geocoding_exact            0
# dtype: int64

# %%
# Check for null values.
for col in us_df.columns:
  null_rate = us_df[col].isnull().sum() / len(us_df) * 100
  if null_rate > 0:
    print(f'Percentage of null values in {col} : {null_rate}%')
# Out:
# Percentage of null values in name : 5.3952645879156425%
# Percentage of null values in armed : 2.7041014361495663%
# Percentage of null values in age : 6.236253072842541%
# Percentage of null values in gender : 0.25876568766981495%
# Percentage of null values in race : 18.889895199896493%
# Percentage of null values in flee : 11.320998835554406%
# Percentage of null values in longitude : 10.829344028981756%
# Percentage of null values in latitude : 10.829344028981756%

# %%
null_percent = us_df.isnull().sum()/us_df.shape[0]*100
null_percent.plot(kind='bar')
plt.title("Percentage of null values in each Column")
plt.show()

# %%
us_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   1          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   2    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   3  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   4     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   5   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
#Drop extra columns
us_df.drop(['id'], inplace = True , axis =1)

# %%
#creating 3 new columns(year, month, day) from Date column 
us_df['date'] = pd.to_datetime(us_df['date'])
us_df['year'] = us_df['date'].dt.year
us_df['month'] = us_df['date'].dt.month
us_df['day'] = us_df['date'].dt.day
us_df.head()
# Out:
#                  name       date   manner_of_death       armed   age gender  \
# 0          Tim Elliot 2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0    A        Shelton    WA                     True       attack
# 1    W          Aloha    OR                    False       attack
# 2    H        Wichita    KS                    False        other
# 3    W  San Francisco    CA                     True       attack
# 4    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact  year  \
# ...

# %%
nan_counts = us_df.isnull().sum()
for column in nan_counts.index:
    nan_count = nan_counts[column]
    us_df[column].fillna(nan_count, inplace=True)
print(nan_counts)
# Out:
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# longitude                  0
# latitude                   0
# is_geocoding_exact         0
# year                       0
# month                      0
# day                        0
# dtype: int64

# %%
# Out:
#                age    longitude     latitude         year        month  \
# count  7729.000000  7729.000000  7729.000000  7729.000000  7729.000000
# mean     64.919136     4.092682   123.352080  2018.419459     6.272739
# std     108.300625   290.701205   248.767444     2.236187     3.418170
# min       2.000000  -160.007000    19.498000  2015.000000     1.000000
# 25%      28.000000  -110.959000    33.725000  2016.000000     3.000000
# 50%      36.000000   -90.229000    37.186000  2018.000000     6.000000
# 75%      48.000000   -80.833000    41.703000  2020.000000     9.000000
# max     482.000000   837.000000   837.000000  2022.000000    12.000000
#
#                day
# count  7729.000000
# mean     15.584810
# std       8.797223
# min       1.000000
# 25%       8.000000
# 50%      16.000000
# 75%      23.000000
# max      31.000000

# %%
print('')
