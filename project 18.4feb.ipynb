# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhatamian/PY/blob/main/project%2018.4feb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing** **libraries** **and** **Create** **Dataframe**

# %%
# importing required libraries
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# creating netflix_movie dataframe
netflix_movies_df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# # **Data Exploration, Data Wrangling and Data Cleaning**

# %%
netflix_movies_df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
netflix_movies_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
netflix_movies_df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
netflix_movies_df.shape
# Out:
# (8807, 12)

# %%
netflix_movies_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
netflix_movies_df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix_movies_df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix_movies_df.duplicated().sum()
# Out:
# 0

# %%
netflix_movies_df.corr()
# Out:
#               release_year
# release_year           1.0

# %%
netflix_movies_df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix_movies_df['release_year'].unique().sum()
# Out:
# 146785

# %%
netflix_movies_df['release_year'].unique().min()
# Out:
# 1925

# %%
netflix_movies_df['rating'].nunique()
# Out:
# 17

# %%
netflix_movies_df['director'].nunique()
# Out:
# 4528

# %%
netflix_movies_df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
#        '140 min', '78 min', '7 Seasons', '64 min', '59 min', '139 min',
#        '69 min', '148 min', '189 min', '141 min', '130 min', '138 min',
#        '81 min', '132 min', '10 Seasons', '123 min', '65 min', '68 min',
#        '66 min', '62 min', '74 min', '131 min', '39 min', '46 min',
#        '38 min', '8 Seasons', '17 Seasons', '126 min', '155 min',
#        '159 min', '137 min', '12 min', '273 min', '36 min', '34 min',
#        '77 min', '60 min', '49 min', '58 min', '72 min', '204 min',
#        '212 min', '25 min', '73 min', '29 min', '47 min', '32 min',
#        '35 min', '71 min', '149 min', '33 min', '15 min', '54 min',
#        '224 min', '162 min', '37 min', '75 min', '79 min', '55 min',
#        '158 min', '164 min', '173 min', '181 min', '185 min', '21 min',
#        '24 min', '51 min', '151 min', '42 min', '22 min', '134 min',
#        '177 min', '13 Seasons', '52 min', '14 min', '53 min', '8 min',
#        '57 min', '28 min', '50 min', '9 min', '26 min', '45 min',
#        '171 min', '27 min', '44 min', '146 min', '20 min', '157 min',
#        '17 min', '203 min', '41 min', '30 min', '194 min', '15 Seasons',
#        '233 min', '237 min', '230 min', '195 min', '253 min', '152 min',
#        '190 min', '160 min', '208 min', '180 min', '144 min', '5 min',
#        '174 min', '170 min', '192 min', '209 min', '187 min', '172 min',
#        '16 min', '186 min', '11 min', '193 min', '176 min', '56 min',
#        '169 min', '40 min', '10 min', '3 min', '168 min', '312 min',
#        '153 min', '214 min', '31 min', '163 min', '19 min', '12 Seasons',
#        nan, '179 min', '11 Seasons', '43 min', '200 min', '196 min',
#        '167 min', '178 min', '228 min', '18 min', '205 min', '201 min',
#        '191 min'], dtype=object)

# %%
netflix_movies_df.duration.dtypes
# Out:
# dtype('O')

# %%
netflix_movies_df['country'].nunique()
# Out:
# 748

# %%
netflix_movies_df['duration'].value_counts()
# Out:
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 16 min          1
# 186 min         1
# 193 min         1
# 189 min         1
# 191 min         1
# Name: duration, Length: 220, dtype: int64

# %%
netflix_movies_df['rating'].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
netflix_movies_df['listed_in'].value_counts()
# Out:
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64

# %%
netflix_movies_df['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
netflix_movies_df['country'].value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
netflix_movies_df['title'].value_counts()
# Out:
# Dick Johnson Is Dead                     1
# Ip Man 2                                 1
# Hannibal Buress: Comedy Camisado         1
# Turbo FAST                               1
# Masha's Tales                            1
#                                         ..
# Love for Sale 2                          1
# ROAD TO ROMA                             1
# Good Time                                1
# Captain Underpants Epic Choice-o-Rama    1
# Zubaan                                   1
# Name: title, Length: 8807, dtype: int64

# %%
netflix_movies_df['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
netflix_movies_df['cast'].value_counts()
# Out:
# David Attenborough                                                                                                                                                                            19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                       14
# Samuel West                                                                                                                                                                                   10
# Jeff Dunham                                                                                                                                                                                    7
# David Spade, London Hughes, Fortune Feimster                                                                                                                                                   6
#                                                                                                                                                                                               ..
# Michael Peña, Diego Luna, Tenoch Huerta, Joaquin Cosio, José María Yazpik, Matt Letscher, Alyssa Diaz                                                                                          1
# Nick Lachey, Vanessa Lachey                                                                                                                                                                    1
# Takeru Sato, Kasumi Arimura, Haru, Kentaro Sakaguchi, Takayuki Yamada, Kendo Kobayashi, Ken Yasuda, Arata Furuta, Suzuki Matsuo, Koichi Yamadera, Arata Iura, Chikako Kaku, Kotaro Yoshida     1
# Toyin Abraham, Sambasa Nzeribe, Chioma Chukwuka Akpotha, Chioma Omeruah, Chiwetalu Agu, Dele Odule, Femi Adebayo, Bayray McNwizu, Biodun Stephen                                               1
# Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy                                                          1
# Name: cast, Length: 7692, dtype: int64

# %%
netflix_movies_df.country.value_counts().head(10)
# Out:
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: country, dtype: int64

# %%
netflix_movies_df.country.value_counts().tail(10)
# Out:
# Mauritius, South Africa                                            1
# United Kingdom, United States, Germany, Denmark, Belgium, Japan    1
# Canada, Norway                                                     1
# India, United Kingdom, Canada, United States                       1
# Philippines, United States                                         1
# Romania, Bulgaria, Hungary                                         1
# Uruguay, Guatemala                                                 1
# France, Senegal, Belgium                                           1
# Mexico, United States, Spain, Colombia                             1
# United Arab Emirates, Jordan                                       1
# Name: country, dtype: int64

# %%
netflix_movies_df.director.value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
netflix_movies_df.rating.value_counts().head(10)
# Out:
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: rating, dtype: int64

# %%
netflix_movies_df.rating.value_counts().tail(10)
# Out:
# PG          287
# TV-G        220
# NR           80
# G            41
# TV-Y7-FV      6
# NC-17         3
# UR            3
# 74 min        1
# 84 min        1
# 66 min        1
# Name: rating, dtype: int64

# %%
netflix_movies_df.release_year.value_counts().head(10)
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: release_year, dtype: int64

# %%
netflix_movies_df.release_year.value_counts().tail(10)
# Out:
# 1956    2
# 1965    2
# 1946    2
# 1942    2
# 1954    2
# 1959    1
# 1925    1
# 1961    1
# 1947    1
# 1966    1
# Name: release_year, dtype: int64

# %%
netflix_movies_df.listed_in.value_counts().head(10)
# Out:
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: listed_in, dtype: int64

# %%
netflix_movies_df.listed_in.value_counts().tail(10)
# Out:
# Docuseries, Reality TV, Teen TV Shows                 1
# Crime TV Shows, International TV Shows, Reality TV    1
# Anime Features, Romantic Movies                       1
# Anime Features, Music & Musicals                      1
# British TV Shows, Kids' TV, TV Thrillers              1
# Kids' TV, TV Action & Adventure, TV Dramas            1
# TV Comedies, TV Dramas, TV Horror                     1
# Children & Family Movies, Comedies, LGBTQ Movies      1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows    1
# Cult Movies, Dramas, Thrillers                        1
# Name: listed_in, dtype: int64

# %%
types = netflix_movies_df['type'].value_counts()

print("Total:" , len(netflix_movies_df))
print("Number of Movies:", types['Movie'])
print("Number of TV Shows:", types['TV Show'])
# Out:
# Total: 8807
# Number of Movies: 6131
# Number of TV Shows: 2676

# %%
netflix_movies_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_movies_df.rename(columns = {'listed_in':'Genre'}, inplace = True)

# %%
netflix_movies_df.rename(columns = {'type':'Category'}, inplace = True)

# %%
netflix_movies_df.head(2)
# Out:
#   show_id Category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                              Genre  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# droping extra columns: show_id, date_added, description in netflix dataframe
netflix_movies_df.drop(['show_id', 'description'], axis=1, inplace=True)

# %%
netflix_movies_df.head()
# Out:
#   Category                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                Genre
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %%
netflix_movies_df.head()
# Out:
#   Category                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                Genre
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %% [markdown]
# ## Cleaning Category colmun

# %%
netflix_movies_df.isnull().sum()
# Out:
# Category           0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# Genre              0
# dtype: int64

# %%
# Check for null values.
for col in netflix_movies_df.columns:
  null_rate = netflix_movies_df[col].isnull().sum() / len(netflix_movies_df) * 100
  if null_rate > 0:
    print(f'Percentage of null values in {col} : {null_rate}%')
# Out:
# Percentage of null values in director : 29.908027705234474%
# Percentage of null values in cast : 9.367548540933349%
# Percentage of null values in country : 9.435676166685592%
# Percentage of null values in date_added : 0.11354604292040424%
# Percentage of null values in rating : 0.04541841716816169%
# Percentage of null values in duration : 0.034063812876121265%

# %%
netflix_movies_df.isnull()
# Out:
#       Category  title  director   cast  country  date_added  release_year  \
# 0        False  False     False   True    False       False         False
# 1        False  False      True  False    False       False         False
# 2        False  False     False  False     True       False         False
# 3        False  False      True   True     True       False         False
# 4        False  False      True  False    False       False         False
# ...        ...    ...       ...    ...      ...         ...           ...
# 8802     False  False     False  False    False       False         False
# 8803     False  False      True   True     True       False         False
# 8804     False  False     False  False    False       False         False
# 8805     False  False     False  False    False       False         False
# 8806     False  False     False  False    False       False         False
#
#       rating  duration  Genre
# 0      False     False  False
# 1      False     False  False
# 2      False     False  False
# 3      False     False  False
# 4      False     False  False
# ...      ...       ...    ...
# 8802   False     False  False
# 8803   False     False  False
# 8804   False     False  False
# 8805   False     False  False
# 8806   False     False  False
#
# [8807 rows x 10 columns]

# %%
sns.heatmap(netflix_movies_df.isnull(),cmap='cividis', cbar_kws={'label': 'Missing Values'})

# %%
netflix_movies_df.Category.hist()
plt.show()

# %%
netflix_movies_df['Category'].isnull().sum()
# Out:
# 0

# %%
netflix_movies_df['Category'].notnull().sum()
# Out:
# 8807

# %% [markdown]
# ##  Cleaning "title" colmun

# %%
netflix_movies_df['title'].isnull().sum()
# Out:
# 0

# %%
netflix_movies_df['title'].notnull().sum()
# Out:
# 8807

# %% [markdown]
# ##  Cleaning "Director" Colmun

# %%
netflix_movies_df['director'].isnull().sum()
# Out:
# 2634

# %%
netflix_movies_df['director'].notnull().sum()
# Out:
# 6173

# %%
netflix_movies_df.director
# Out:
# 0       Kirsten Johnson
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
#              ...
# 8802      David Fincher
# 8803                NaN
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
# filling null values with "Unknown"
netflix_movies_df['director'].fillna('Unknown', inplace=True)

# %%
netflix_movies_df['director'].isnull().sum()
# Out:
# 0

# %%
netflix_movies_df.shape
# Out:
# (8807, 10)

# %%
netflix_movies_df.director
# Out:
# 0       Kirsten Johnson
# 1               Unknown
# 2       Julien Leclercq
# 3               Unknown
# 4               Unknown
#              ...
# 8802      David Fincher
# 8803            Unknown
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
netflix_movies_df.head()
# Out:
#   Category                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water          Unknown
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans          Unknown
# 4  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                Genre
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %%
netflix_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   Genre         8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %% [markdown]
# ## Cleaning "cast" colmun

# %%
netflix_movies_df['cast'].isnull().sum()
# Out:
# 825

# %%
netflix_movies_df['cast'].notnull().sum()
# Out:
# 7982

# %%
# filling null values with "Unknown"
netflix_movies_df['cast'].fillna('Unknown', inplace=True)

# %%
netflix_movies_df['cast'].isnull().sum()
# Out:
# 0

# %%
netflix_movies_df.head(5)
# Out:
#   Category                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water          Unknown
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans          Unknown
# 4  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                            Unknown            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                Genre
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %% [markdown]
# ## Cleaning "country" colmun

# %%
netflix_movies_df['country'].isnull().sum()
# Out:
# 831

# %%
netflix_movies_df['country'].notnull().sum()
# Out:
# 7976

# %%
# drop all null values 
netflix_movies_df.dropna(subset=['country'], inplace=True)

# %%
netflix_movies_df.shape
# Out:
# (7976, 10)

# %%
netflix_movies_df.head()
# Out:
#   Category                          title         director  \
# 0    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show                  Blood & Water          Unknown
# 4  TV Show                   Kota Factory          Unknown
# 7    Movie                        Sankofa     Haile Gerima
# 8  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 0                                            Unknown
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 4                                              India  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 4          2021  TV-MA  2 Seasons
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                                Genre
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 4  International TV Shows, Romantic TV Shows, TV ...
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV

# %% [markdown]
# ## Cleaning date_added colmun

# %%
netflix_movies_df['date_added'].isnull().sum()
# Out:
# 9

# %%
netflix_movies_df[netflix_movies_df['date_added'].isna()]
# Out:
#      Category                                        title director  \
# 6066  TV Show  A Young Doctor's Notebook and Other Stories  Unknown
# 6174  TV Show              Anthony Bourdain: Parts Unknown  Unknown
# 6795  TV Show                                      Frasier  Unknown
# 6806  TV Show                                      Friends  Unknown
# 6901  TV Show                              Gunslinger Girl  Unknown
# 7254  TV Show                          La Familia P. Luche  Unknown
# 7406  TV Show                                        Maron  Unknown
# 7847  TV Show                                 Red vs. Blue  Unknown
# 8182  TV Show                 The Adventures of Figaro Pho  Unknown
#
#                                                    cast         country  \
# 6066  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6174                                   Anthony Bourdain   United States
# 6795  Kelsey Grammer, Jane Leeves, David Hyde Pierce...   United States
# 6806  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
# 6901  Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...           Japan
# 7254  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...   United States
# 7406  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 7847  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 8182  Luke Jurevicius, Craig Behenna, Charlotte Haml...       Australia
#
#      date_added  release_year rating    duration  \
# 6066        NaN          2013  TV-MA   2 Seasons
# 6174        NaN          2018  TV-PG   5 Seasons
# 6795        NaN          2003  TV-PG  11 Seasons
# 6806        NaN          2003  TV-14  10 Seasons
# 6901        NaN          2008  TV-14   2 Seasons
# 7254        NaN          2012  TV-14   3 Seasons
# 7406        NaN          2016  TV-MA   4 Seasons
# 7847        NaN          2015     NR  13 Seasons
# 8182        NaN          2015  TV-Y7   2 Seasons
#
#                                                   Genre
# 6066           British TV Shows, TV Comedies, TV Dramas
# 6174                                         Docuseries
# 6795                     Classic & Cult TV, TV Comedies
# 6806                     Classic & Cult TV, TV Comedies
# 6901                       Anime Series, Crime TV Shows
# 7254  International TV Shows, Spanish-Language TV Sh...
# 7406                                        TV Comedies
# 7847  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 8182                              Kids' TV, TV Comedies

# %%
netflix_movies_df.dropna(subset=['date_added'], inplace=True)

# %%
netflix_movies_df['date_added'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Cleaning "rating" colmun

# %%
netflix_movies_df['rating'].isnull().sum()
# Out:
# 3

# %%
netflix_movies_df[netflix_movies_df['rating'].isna()]
# Out:
#      Category                              title         director  \
# 6827  TV Show  Gargantia on the Verdurous Planet          Unknown
# 7312  TV Show                       Little Lunch          Unknown
# 7537    Movie               My Honor Was Loyalty  Alessandro Pepe
#
#                                                    cast    country  \
# 6827  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...      Japan
# 7312  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...  Australia
# 7537  Leone Frisa, Paolo Vaccarino, Francesco Miglio...      Italy
#
#             date_added  release_year rating  duration  \
# 6827  December 1, 2016          2013    NaN  1 Season
# 7312  February 1, 2018          2015    NaN  1 Season
# 7537     March 1, 2017          2015    NaN   115 min
#
#                                      Genre
# 6827  Anime Series, International TV Shows
# 7312                 Kids' TV, TV Comedies
# 7537                                Dramas

# %%
netflix_movies_df.dropna(subset=['rating'], inplace=True)

# %% [markdown]
# ## Cleaning "duration" colmun

# %%
netflix_movies_df['duration'].isnull().sum()
# Out:
# 3

# %%
netflix_movies_df[netflix_movies_df['duration'].isna()]
# Out:
#      Category                                 title    director        cast  \
# 5541    Movie                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# 5794    Movie                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# 5813    Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#             country          date_added  release_year  rating duration   Genre
# 5541  United States       April 4, 2017          2017  74 min      NaN  Movies
# 5794  United States  September 16, 2016          2010  84 min      NaN  Movies
# 5813  United States     August 15, 2016          2015  66 min      NaN  Movies

# %%
netflix_movies_df.dropna(subset=['duration'], inplace=True)

# %%
netflix_movies_df.shape
# Out:
# (7961, 10)

# %% [markdown]
# ## Result of Cleaning

# %%
sns.heatmap(netflix_movies_df.isnull(), cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
netflix_movies_df.isnull().sum()
# Out:
# Category        0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# Genre           0
# dtype: int64

# %%
netflix_movies_df["date_added"] = pd.to_datetime(netflix_movies_df['date_added'])
netflix_movies_df['day_added'] = netflix_movies_df['date_added'].dt.day.astype(int)
netflix_movies_df['year_added'] = netflix_movies_df['date_added'].dt.year.astype(int)
netflix_movies_df['month_added'] = netflix_movies_df['date_added'].dt.month.astype(int)

# %%
netflix_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7961 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Category         7961 non-null   object
#  1   title            7961 non-null   object
#  2   director         7961 non-null   object
#  3   cast             7961 non-null   object
#  4   country          7961 non-null   object
#  5   date_added       7961 non-null   datetime64[ns]
#  6   release_year     7961 non-null   int64
#  7   rating           7961 non-null   object
#  8   duration         7961 non-null   object
#  9   Genre            7961 non-null   object
#  10  day_added        7961 non-null   int64
#  11  year_added       7961 non-null   int64
#  12  month_added      7961 non-null   int64
#  13  Duration_number  7961 non-null   int64
#  14  Unit             7961 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(9)
# memory usage: 995.1+ KB

# %%
netflix_movies_df.shape
# Out:
# (7961, 15)

# %%
netflix_movies_df.head(2)
# Out:
#   Category                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                              Genre  day_added  year_added  \
# 0                                    Documentaries         25        2021
# 1  International TV Shows, TV Dramas, TV Mysteries         24        2021
#
#    month_added  Duration_number     Unit
# 0            9               90      min
# 1            9                2  Seasons

# %%
netflix_movies_df.describe()
# Out:
#        release_year    day_added   year_added  month_added  Duration_number
# count   7961.000000  7961.000000  7961.000000  7961.000000      7961.000000
# mean    2013.888079    12.302977  2018.796634     6.637608        72.331617
# std        8.963881     9.895352     1.562747     3.490862        50.134358
# min     1942.000000     1.000000  2008.000000     1.000000         1.000000
# 25%     2013.000000     1.000000  2018.000000     4.000000         3.000000
# 50%     2017.000000    12.000000  2019.000000     7.000000        90.000000
# 75%     2019.000000    20.000000  2020.000000    10.000000       107.000000
# max     2021.000000    31.000000  2021.000000    12.000000       312.000000

# %%
netflix_movies_df.corr()
# Out:
#                  release_year  day_added  year_added  month_added  \
# release_year         1.000000   0.142107    0.088200    -0.040593
# day_added            0.142107   1.000000    0.023686     0.023276
# year_added           0.088200   0.023686    1.000000    -0.162943
# month_added         -0.040593   0.023276   -0.162943     1.000000
# Duration_number     -0.246186  -0.077983    0.034228    -0.014482
#
#                  Duration_number
# release_year           -0.246186
# day_added              -0.077983
# year_added              0.034228
# month_added            -0.014482
# Duration_number         1.000000

# %% [markdown]
# ## **Data Exploration After Cleaning the data**

# %%
netflix_movies_df[netflix_movies_df['director'].str.contains('Martin Scorsese', na=False)]
# Out:
#      Category                                              title  \
# 1358    Movie                                     Shutter Island
# 2632    Movie                       No Direction Home: Bob Dylan
# 2860    Movie                                               Hugo
# 3227    Movie                                       The Irishman
# 3759    Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 6111    Movie                    Alice Doesn't Live Here Anymore
# 6826    Movie                                  Gangs of New York
# 6880    Movie                                         GoodFellas
# 7431    Movie                                       Mean Streets
# 7820    Movie                                        Raging Bull
# 8272    Movie                                       The Departed
# 8735    Movie                    Who's That Knocking at My Door?
#
#              director                                               cast  \
# 1358  Martin Scorsese  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 2632  Martin Scorsese  Bob Dylan, Joan Baez, Dave Van Ronk, Peter Yar...
# 2860  Martin Scorsese  Ben Kingsley, Sacha Baron Cohen, Asa Butterfie...
# 3227  Martin Scorsese  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...
# 3759  Martin Scorsese  Bob Dylan, Allen Ginsberg, Joan Baez, Patti Sm...
# 6111  Martin Scorsese  Ellen Burstyn, Kris Kristofferson, Billy Green...
# 6826  Martin Scorsese  Leonardo DiCaprio, Daniel Day-Lewis, Cameron D...
# 6880  Martin Scorsese  Robert De Niro, Ray Liotta, Joe Pesci, Lorrain...
# 7431  Martin Scorsese  Robert De Niro, Harvey Keitel, David Proval, A...
# 7820  Martin Scorsese  Robert De Niro, Cathy Moriarty, Joe Pesci, Fra...
# 55   2021-09-15          2021  TV-PG  6 Seasons
# 67   2021-09-15          1994  TV-PG  9 Seasons
# 82   2021-09-10          2021  TV-14  6 Seasons
# ...         ...           ...    ...        ...
# 8710 2014-04-01          2012  TV-MA  8 Seasons
# 8726 2018-12-29          2017  TV-PG  5 Seasons
# 8747 2018-12-15          2016   TV-G   1 Season
# 8755 2016-11-01          2010  TV-14  3 Seasons
# 8780 2016-04-01          2015  TV-Y7   1 Season
#
#                                        Genre  day_added  year_added  \
# 15                    TV Comedies, TV Dramas         22        2021
# 40             Kids' TV, TV Sci-Fi & Fantasy         16        2021
# 55                                Reality TV         15        2021
# 67                     Kids' TV, TV Comedies         15        2021
# 82    Crime TV Shows, TV Comedies, TV Dramas         10        2021
# ...                                      ...        ...         ...
# 8710                  TV Comedies, TV Dramas          1        2014
# 8726                               TV Dramas         29        2018
# 8747                              Reality TV         15        2018
# 8755              Crime TV Shows, Docuseries          1        2016
# 8780                  Anime Series, Kids' TV          1        2016
#
#       month_added
# 15              9
# 40              9
# 55              9
# 67              9
# 82              9
# ...           ...
# 8710            4
# 8726           12
# 8747           12
# 8755           11
# 8780            4
#
# [754 rows x 13 columns]

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'TV Show') & (netflix_movies_df['country'] == 'United States')] ['title']
# Out:
# 15                           Dear White People
# 40      He-Man and the Masters of the Universe
# 55                                   Nailed It
# 67                           Saved by the Bell
# 82                                     Lucifer
#                          ...
# 8710                                     Weeds
# 8726                      When Calls the Heart
# 8747                                 Winsanity
# 8755                         Women Behind Bars
# 8780                              Yo-Kai Watch
# Name: title, Length: 754, dtype: object

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'TV Show') & (netflix_movies_df['Genre'] == 'Documentaries') | (netflix_movies_df['country'] == 'United Kingdom')]
# Out:
#      Category                                   title         director  \
# 8     TV Show           The Great British Baking Show  Andy Devonshire
# 32    TV Show                           Sex Education          Unknown
# 65    TV Show                            Numberblocks          Unknown
# 72    TV Show  Jack Whitehall: Travels with My Father          Unknown
# 98    TV Show               Octonauts: Above & Beyond          Unknown
# ...       ...                                     ...              ...
# 8740  TV Show                             Wild Alaska          Unknown
# 8741  TV Show                             Wild Arabia          Unknown
# 8744    Movie                                Williams  Morgan Matthews
# 8758  TV Show                  World's Busiest Cities          Unknown
# 8786    Movie                            You Can Tutu      James Brown
#
#                                                    cast         country  \
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 32    Asa Butterfield, Gillian Anderson, Ncuti Gatwa...  United Kingdom
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom
# 72                    Jack Whitehall, Michael Whitehall  United Kingdom
# 98    Antonio Aakeel, Chipo Chung, Simon Foster, Ter...  United Kingdom
# ...                                                 ...             ...
# 8740                                      Dougray Scott  United Kingdom
# 8741                                   Alexander Siddig  United Kingdom
# 8744                                            Unknown  United Kingdom
# 8758                 Anita Rani, Ade Adepitan, Dan Snow  United Kingdom
# 8786  Lily O'Regan, Jeannettsy Enriquez Borges, Joel...  United Kingdom
#
#      date_added  release_year rating   duration  \
# 8    2021-09-24          2021  TV-14  9 Seasons
# 32   2021-09-17          2020  TV-MA  3 Seasons
# 65   2021-09-15          2021   TV-Y  6 Seasons
# 72   2021-09-14          2021  TV-MA  5 Seasons
# 98   2021-09-07          2021   TV-Y   1 Season
# ...         ...           ...    ...        ...
# 8740 2017-03-31          2015  TV-PG   1 Season
# 8741 2017-03-31          2013  TV-PG   1 Season
# 8744 2017-11-04          2017  TV-MA    105 min
# 8758 2019-02-01          2017  TV-PG   1 Season
# 8786 2017-12-31          2017   TV-G     87 min
#
#                                                   Genre  day_added  \
# 8                          British TV Shows, Reality TV         24
# 32    British TV Shows, International TV Shows, TV C...         17
# 65                                             Kids' TV         15
# 72    British TV Shows, Docuseries, International TV...         14
# 98                           British TV Shows, Kids' TV          7
# ...                                                 ...        ...
# 8740  British TV Shows, Docuseries, Science & Nature TV         31
# 8741  British TV Shows, Docuseries, Science & Nature TV         31
# 8744  Documentaries, International Movies, Sports Mo...          4
# 8758                       British TV Shows, Docuseries          1
# 8786                           Children & Family Movies         31
#
#       year_added  month_added
# 8           2021            9
# 32          2021            9
# 65          2021            9
# 72          2021            9
# 98          2021            9
# ...          ...          ...
# 8740        2017            3
# 8741        2017            3
# 8744        2017           11
# 8758        2019            2
# 8786        2017           12
#
# [418 rows x 13 columns]

# %%
netflix_movies_df[netflix_movies_df['cast'].str.contains('Tom Cruise')]
# Out:
#      Category     title              director  \
# 341     Movie  Magnolia  Paul Thomas Anderson
# 1254    Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                       Genre  \
# 341  2021-08-01          1999      R  189 min  Dramas, Independent Movies
# 1254 2021-03-01          1988      R  134 min      Classic Movies, Dramas
#
#       day_added  year_added  month_added
# 341           1        2021            8
# 1254          1        2021            3

# %%
netflix_movies_df[netflix_movies_df['cast'].str.contains('Daniel Craig')]
# Out:
#      Category                            title             director  \
# 891     Movie                       Layer Cake       Matthew Vaughn
# 3223    Movie                         Defiance         Edward Zwick
# 6427    Movie                    Casino Royale      Martin Campbell
# 7211    Movie                            Kings  Deniz Gamze Ergüven
# 7809    Movie                Quantum of Solace         Marc Forster
# 8184    Movie         The Adventures of Tintin     Steven Spielberg
# 8320    Movie  The Girl with the Dragon Tattoo        David Fincher
#
#                                                    cast  \
# 891   Daniel Craig, Colm Meaney, Kenneth Cranham, Si...
# 3223  Daniel Craig, Liev Schreiber, Jamie Bell, Alex...
# 6427  Daniel Craig, Judi Dench, Eva Green, Jeffrey W...
# 7211  Halle Berry, Daniel Craig, Lamar Johnson, Kaal...
# 7809  Daniel Craig, Olga Kurylenko, Mathieu Amalric,...
# 8184  Jamie Bell, Andy Serkis, Daniel Craig, Nick Fr...
# 8320  Daniel Craig, Rooney Mara, Christopher Plummer...
#
#                                                 country date_added  \
# 891                                      United Kingdom 2021-05-13
# 3223                                      United States 2019-11-27
# 6427  United Kingdom, Czech Republic, United States,... 2020-08-31
# 7211              France, Belgium, China, United States 2018-10-29
# 7809                      United Kingdom, United States 2020-08-31
# 8184         United States, New Zealand, United Kingdom 2019-11-20
# 8320                      United States, Sweden, Norway 2021-01-05
#
#       release_year rating duration  \
# 891           2004      R  105 min
# 3223          2008      R  137 min
# 6427          2006  PG-13  145 min
# 7211          2017      R   87 min
# 7809          2008  PG-13  106 min
# 8184          2011     PG  107 min
# 8320          2011      R  158 min
#
#                                                   Genre  day_added  \
# 891   Independent Movies, International Movies, Thri...         13
# 3223                         Action & Adventure, Dramas         27
# 6427                                 Action & Adventure         31
# 7211                                             Dramas         29
# 7809                                 Action & Adventure         31
# 8184                           Children & Family Movies         20
# 8320                                  Dramas, Thrillers          5
#
#       year_added  month_added
# 891         2021            5
# 3223        2019           11
# 6427        2020            8
# 7211        2018           10
# 7809        2020            8
# 8184        2019           11
# 8320        2021            1

# %%
netflix_movies_df[netflix_movies_df['cast'].str.contains('Jennifer Lawrence')]
# Out:
#      Category                           title          director  \
# 251     Movie                      Like Crazy     Drake Doremus
# 702     Movie         Silver Linings Playbook  David O. Russell
# 7009    Movie  House at the End of the Street     Mark Tonderai
# 8750    Movie                   Winter's Bone      Debra Granik
#
#                                                    cast  \
# 251   Anton Yelchin, Felicity Jones, Jennifer Lawren...
# 702   Bradley Cooper, Jennifer Lawrence, Robert De N...
# 7009  Gil Bellows, Max Thieriot, Jennifer Lawrence, ...
# 8750  Jennifer Lawrence, John Hawkes, Kevin Breznaha...
#
#                     country date_added  release_year rating duration  \
# 251           United States 2021-08-19          2011  PG-13   91 min
# 702           United States 2021-06-17          2012      R  122 min
# 7009  United States, Canada 2020-05-08          2012  PG-13  101 min
# 8750          United States 2019-03-01          2010      R  100 min
#
#                                             Genre  day_added  year_added  \
# 251   Dramas, Independent Movies, Romantic Movies         19        2021
# 702          Comedies, Dramas, Independent Movies         17        2021
# 7009                     Horror Movies, Thrillers          8        2020
# 8750                   Dramas, Independent Movies          1        2019
#
#       month_added
# 251             8
# 702             6
# 7009            5
# 8750            3

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'Movie') & (netflix_movies_df['rating'] == 'PG-13')]
# Out:
#      Category                    title         director  \
# 0       Movie     Dick Johnson Is Dead  Kirsten Johnson
# 9       Movie             The Starling   Theodore Melfi
# 27      Movie                Grown Ups     Dennis Dugan
# 28      Movie               Dark Skies    Scott Stewart
# 29      Movie                 Paranoia   Robert Luketic
# ...       ...                      ...              ...
# 8757    Movie       World Trade Center     Oliver Stone
# 8764    Movie               Wyatt Earp  Lawrence Kasdan
# 8766    Movie                      XXx        Rob Cohen
# 8767    Movie  XXX: State of the Union     Lee Tamahori
# 8782    Movie              Yoga Hosers      Kevin Smith
#
#                                                    cast  \
# 0                                               Unknown
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 27    Adam Sandler, Kevin James, Chris Rock, David S...
# 28    Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 29    Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...                                                 ...
# 8757  Nicolas Cage, Michael Peña, Maggie Gyllenhaal,...
# 8764  Kevin Costner, Dennis Quaid, Gene Hackman, Dav...
# 8766  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 8767  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 8782  Harley Quinn Smith, Lily-Rose Depp, Johnny Dep...
#
#                            country date_added  release_year rating duration  \
# 0                    United States 2021-09-25          2020  PG-13   90 min
# 9                    United States 2021-09-24          2021  PG-13  104 min
# 27                   United States 2021-09-20          2010  PG-13  103 min
# 28                   United States 2021-09-19          2013  PG-13   97 min
# 29    United States, India, France 2021-09-19          2013  PG-13  106 min
# ...                            ...        ...           ...    ...      ...
# 8757                 United States 2019-11-20          2006  PG-13  129 min
# 8764                 United States 2020-01-01          1994  PG-13  191 min
# 8766                 United States 2019-01-01          2002  PG-13  124 min
# 8767                 United States 2019-01-01          2005  PG-13  101 min
# 8782                 United States 2016-12-02          2016  PG-13   88 min
#
#                                             Genre  day_added  year_added  \
# 0                                   Documentaries         25        2021
# 9                                Comedies, Dramas         24        2021
# 27                                       Comedies         20        2021
# 28                Horror Movies, Sci-Fi & Fantasy         19        2021
# 29                                      Thrillers         19        2021
# ...                                           ...        ...         ...
# 8757                   Action & Adventure, Dramas         20        2019
# 8764                           Action & Adventure          1        2020
# 8766            Action & Adventure, Sports Movies          1        2019
# 8767                           Action & Adventure          1        2019
# 8782  Comedies, Horror Movies, Independent Movies          2        2016
#
#       month_added
# 0               9
# 9               9
# 27              9
# 28              9
# 29              9
# ...           ...
# 8757           11
# 8764            1
# 8766            1
# 8767            1
# 8782           12
#
# [482 rows x 13 columns]

# %%
netflix_movies_df[((netflix_movies_df['Category'] == 'Movie') & (netflix_movies_df['rating'] == 'TV-G')) | ((netflix_movies_df['Category'] == 'TV Show') & (netflix_movies_df['rating'] == 'TV-G'))]
# Out:
#      Category                                         title        director  \
# 66    TV Show                 Raja Rasoi Aur Anya Kahaniyan         Unknown
# 106   TV Show                                        Bunk'd         Unknown
# 108   TV Show                                     Dive Club         Unknown
# 232   TV Show                              Wheel of Fortune         Unknown
# 506     Movie                      This Little Love Of Mine  Christine Luby
# ...       ...                                           ...             ...
# 8619    Movie  Treasures from the Wreck of the Unbelievable   Sam Hobkinson
# 8669  TV Show                                 V.R. Troopers         Unknown
# 8702    Movie                                   Waterschool    Tiffanie Hsu
# 8747  TV Show                                     Winsanity         Unknown
# 8786    Movie                                  You Can Tutu     James Brown
#
#                                                    cast  \
# 66                                              Unknown
# 106   Peyton List, Karan Brar, Skai Jackson, Miranda...
# 108   Aubri Ibrag, Sana'a Shaik, Miah Madden, Mercy ...
# 232                              Pat Sajak, Vanna White
# 506   Saskia Hampele, Liam McIntyre, Lynn Gilmartin,...
# ...                                                 ...
# 8619                                            Unknown
# 8669  Michael Sorich, Gardner Baldwin, Mike Reynolds...
# 8702                                            Unknown
# 8747                                      Donald Faison
# 8786  Lily O'Regan, Jeannettsy Enriquez Borges, Joel...
#
#                                           country date_added  release_year  \
# 66                                          India 2021-09-15          2014
# 106                                 United States 2021-09-05          2021
# 108                                     Australia 2021-09-03          2021
# 232                                 United States 2021-08-25          2019
# 506                                     Australia 2021-07-07          2021
# ...                                           ...        ...           ...
# 8619                               United Kingdom 2018-01-01          2017
# 8669                                United States 2016-01-01          1995
# 8702  United States, Brazil, India, Uganda, China 2018-07-25          2018
# 8747                                United States 2018-12-15          2016
# 8786                               United Kingdom 2017-12-31          2017
#
#      rating   duration                                        Genre  \
# 66     TV-G   1 Season           Docuseries, International TV Shows
# 106    TV-G  5 Seasons                        Kids' TV, TV Comedies
# 108    TV-G   1 Season           Kids' TV, TV Dramas, Teen TV Shows
# 232    TV-G  3 Seasons                                   Reality TV
# 506    TV-G     92 min        International Movies, Romantic Movies
# ...     ...        ...                                          ...
# 8619   TV-G     82 min  Documentaries, Dramas, International Movies
# 8669   TV-G  2 Seasons                                     Kids' TV
# 8702   TV-G     68 min                                Documentaries
# 8747   TV-G   1 Season                                   Reality TV
# 8786   TV-G     87 min                     Children & Family Movies
#
#       day_added  year_added  month_added
# 66           15        2021            9
# 106           5        2021            9
# 108           3        2021            9
# 232          25        2021            8
# 506           7        2021            7
# ...         ...         ...          ...
# 8619          1        2018            1
# 8669          1        2016            1
# 8702         25        2018            7
# 8747         15        2018           12
# 8786         31        2017           12
#
# [190 rows x 13 columns]

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'Movie') & (netflix_movies_df['rating'] == 'PG-13') ].shape
# Out:
# (482, 13)

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'Movie') & (netflix_movies_df['rating'] == 'PG-13') & (netflix_movies_df['country']== 'Canada')]
# Out:
#      Category               title      director  \
# 8100    Movie    Strange but True  Rowan Athale
# 8253    Movie    The Confirmation    Bob Nelson
# 8659    Movie  Undercover Grandpa   Erik Canuel
#
#                                                    cast country date_added  \
# 8100  Amy Ryan, Nick Robinson, Margaret Qualley, Gre...  Canada 2020-08-30
# 8253  Clive Owen, Maria Bello, Patton Oswalt, Jaeden...  Canada 2019-02-06
# 8659  James Caan, Jessica Walter, Louis Gossett Jr.,...  Canada 2017-11-01
#
#       release_year rating duration  \
# 8100          2019  PG-13   96 min
# 8253          2016  PG-13  101 min
# 8659          2016  PG-13   94 min
#
#                                                   Genre  day_added  \
# 8100                                  Dramas, Thrillers         30
# 8253               Comedies, Dramas, Independent Movies          6
# 8659  Action & Adventure, Children & Family Movies, ...          1
#
#       year_added  month_added
# 8100        2020            8
# 8253        2019            2
# 8659        2017           11

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'Movie') & (netflix_movies_df['rating'] == 'PG-13') & (netflix_movies_df['country']== 'Canada')].shape
# Out:
# (3, 13)

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'TV Show') & (netflix_movies_df['rating'] == 'R')]
# Out:
#      Category  title director  \
# 7593  TV Show  Nobel  Unknown
#
#                                                    cast country date_added  \
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway 2016-12-10
#
#       release_year rating  duration  \
# 7593          2016      R  1 Season
#
#                                                 Genre  day_added  year_added  \
# 7593  International TV Shows, TV Dramas, TV Thrillers         10        2016
#
#       month_added
# 7593           12

# %%
netflix_movies_df[(netflix_movies_df['Category'] == 'TV Show') & (netflix_movies_df['rating'] == 'R') & (netflix_movies_df['release_year'] > 2003)]
# Out:
#      Category  title director  \
# 7593  TV Show  Nobel  Unknown
#
#                                                    cast country date_added  \
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway 2016-12-10
#
#       release_year rating  duration  \
# 7593          2016      R  1 Season
#
#                                                 Genre  day_added  year_added  \
# 7593  International TV Shows, TV Dramas, TV Thrillers         10        2016
#
#       month_added
# 7593           12

# %%
netflix_movies_df[['Duration_number', 'Unit']] = netflix_movies_df['duration'].str.split(' ', expand = True)

# %%
netflix_movies_df[['Duration_number', 'Unit']]
# Out:
#      Duration_number     Unit
# 0                 90      min
# 1                  2  Seasons
# 4                  2  Seasons
# 7                125      min
# 8                  9  Seasons
# ...              ...      ...
# 8801              96      min
# 8802             158      min
# 8804              88      min
# 8805              88      min
# 8806             111      min
#
# [7961 rows x 2 columns]

# %%
netflix_movies_df['Duration_number'] = pd.to_numeric(netflix_movies_df['Duration_number'], errors='coerce')
netflix_movies_df['Duration_number'].max()
# Out:
# 312

# %%
netflix_movies_df['Duration_number'].min()
# Out:
# 1

# %%
netflix_movies_df['Duration_number'].mean()
# Out:
# 72.3316166310765

# %%
netflix_movies_df_only_TV_Show = netflix_movies_df[netflix_movies_df['Category'] == 'TV Show']

# %%
netflix_movies_df_only_TV_Show.head(5)
# Out:
#    Category                          title         director  \
# 1   TV Show                  Blood & Water          Unknown
# 4   TV Show                   Kota Factory          Unknown
# 8   TV Show  The Great British Baking Show  Andy Devonshire
# 15  TV Show              Dear White People          Unknown
# 17  TV Show                Falsa identidad          Unknown
#
#                                                  cast         country  \
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...           India
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...   United States
# 17  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...          Mexico
#
#    date_added  release_year rating   duration  \
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 4  2021-09-24          2021  TV-MA  2 Seasons
# 8  2021-09-24          2021  TV-14  9 Seasons
# 15 2021-09-22          2021  TV-MA  4 Seasons
# 17 2021-09-22          2020  TV-MA  2 Seasons
#
#                                                 Genre  day_added  year_added  \
# 1     International TV Shows, TV Dramas, TV Mysteries         24        2021
# 4   International TV Shows, Romantic TV Shows, TV ...         24        2021
# 8                        British TV Shows, Reality TV         24        2021
# 15                             TV Comedies, TV Dramas         22        2021
# 17  Crime TV Shows, Spanish-Language TV Shows, TV ...         22        2021
#
#     month_added  Duration_number     Unit
# 1             9                2  Seasons
# 4             9                2  Seasons
# 8             9                9  Seasons
# 15            9                4  Seasons
# 17            9                2  Seasons

# %%
netflix_movies_df_only_TV_Show.country.value_counts()
# Out:
# United States                                    754
# United Kingdom                                   212
# Japan                                            167
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
#country which has the highest number of TV Show
netflix_movies_df_only_TV_Show.country.value_counts().head(1)
# Out:
# United States    754
# Name: country, dtype: int64

# %%
netflix_movies_df.sort_values(by='release_year')
# Out:
#      Category                                          title  \
# 7790    Movie                                 Prelude to War
# 8205    Movie                           The Battle of Midway
# 8660    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739    Movie             Why We Fight: The Battle of Russia
# 8763    Movie                WWII: Report from the Aleutians
# ...       ...                                            ...
# 1466    Movie                   The Minimalists: Less Is Now
# 1136    Movie                           Tersanjung the Movie
# 538   TV Show                                     The A List
# 1167    Movie                               Caught by a Wave
# 1151    Movie                   Octonauts & the Ring of Fire
#
#                                director  \
# 7790                        Frank Capra
# 8205                          John Ford
# 8660                          John Ford
# 8739        Frank Capra, Anatole Litvak
# 8763                        John Huston
# ...                                 ...
# 1466                            Unknown
# 1136  Hanung Bramantyo, Pandu Adjisurya
# 538                             Unknown
# 1167               Massimiliano Camaiti
# 1151                      Blair Simmons
#
#                                                    cast  \
# 7790                                            Unknown
# 8205                          Henry Fonda, Jane Darwell
# 8660                                            Unknown
# 8739                                            Unknown
# 8763                                            Unknown
# ...                                                 ...
# 1466                                            Unknown
# 1136  Clara Bernadeth, Giorgino Abraham, Kevin Ardil...
# 538   Lisa Ambalavanar, Ellie Duckles, Savannah Bake...
# 1167  Elvira Camarrone, Christian Roberto, Donatella...
# 1151  Simon Greenall, Rob Rackstraw, Jo Wyatt, Paul ...
#
#                     country date_added  release_year rating   duration  \
# 7790          United States 2017-03-31          1942  TV-14     52 min
# 8205          United States 2017-03-31          1942  TV-14     18 min
# 8660          United States 2017-03-31          1943  TV-PG     61 min
# 8739          United States 2017-03-31          1943  TV-PG     82 min
# 8763          United States 2017-03-31          1943  TV-PG     45 min
# ...                     ...        ...           ...    ...        ...
# 1466          United States 2021-01-01          2021  TV-14     54 min
# 1136              Indonesia 2021-04-01          2021  TV-14    114 min
# 538          United Kingdom 2021-07-06          2021  TV-PG  2 Seasons
# 1167                  Italy 2021-03-25          2021  TV-14    100 min
# 1151  China, United Kingdom 2021-03-30          2021   TV-Y     73 min
#
#                                                   Genre  day_added  \
# 7790                      Classic Movies, Documentaries         31
# 8205                      Classic Movies, Documentaries         31
# 8660                      Classic Movies, Documentaries         31
# 8739                                      Documentaries         31
# 8763                                      Documentaries         31
# ...                                                 ...        ...
# 1466                                      Documentaries          1
# 1136      Dramas, International Movies, Romantic Movies          1
# 538   British TV Shows, International TV Shows, TV D...          6
# 1167      Dramas, International Movies, Romantic Movies         25
# 1151                           Children & Family Movies         30
#
#       year_added  month_added  Duration_number     Unit
# 7790        2017            3               52      min
# 8205        2017            3               18      min
# 8660        2017            3               61      min
# 8739        2017            3               82      min
# 8763        2017            3               45      min
# ...          ...          ...              ...      ...
# 1466        2021            1               54      min
# 1136        2021            4              114      min
# 538         2021            7                2  Seasons
# 1167        2021            3              100      min
# 1151        2021            3               73      min
#
# [7961 rows x 15 columns]

# %%
#The newest movies and tv show are shown 
netflix_movies_df.sort_values(by='release_year', ascending=False)
# Out:
#      Category                                          title  \
# 1093  TV Show                                    The Big Day
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#      date_added  release_year rating   duration  \
# 0    2021-09-25          2020  PG-13     90 min
# 9    2021-09-24          2021  PG-13    104 min
# 15   2021-09-22          2021  TV-MA  4 Seasons
# 27   2021-09-20          2010  PG-13    103 min
# 28   2021-09-19          2013  PG-13     97 min
# ...         ...           ...    ...        ...
# 8791 2019-11-20          2011      R     94 min
# 8793 2019-11-20          2005     PG     88 min
# 8802 2019-11-20          2007      R    158 min
# 8804 2019-11-01          2009      R     88 min
# 8805 2020-01-11          2006     PG     88 min
#
#                                      Genre  day_added  year_added  \
# 0                            Documentaries         25        2021
# 9                         Comedies, Dramas         24        2021
# 15                  TV Comedies, TV Dramas         22        2021
# 27                                Comedies         20        2021
# 28         Horror Movies, Sci-Fi & Fantasy         19        2021
# ...                                    ...        ...         ...
# 8791  Comedies, Dramas, Independent Movies         20        2019
# 8793    Children & Family Movies, Comedies         20        2019
# 8802        Cult Movies, Dramas, Thrillers         20        2019
# 8804               Comedies, Horror Movies          1        2019
# 8805    Children & Family Movies, Comedies         11        2020
#
#       month_added  Duration_number     Unit
# 0               9               90      min
# 9               9              104      min
# 15              9                4  Seasons
# 27              9              103      min
# 28              9               97      min
# ...           ...              ...      ...
# 8791           11               94      min
# 8793           11               88      min
# 8802           11              158      min
# 8804           11               88      min
# 8805            1               88      min
#
# [2809 rows x 15 columns]

# %%
netflix_movies_df[(netflix_movies_df['country'] == 'United States') & (netflix_movies_df['rating'] == 'R') & 
                  (netflix_movies_df['Genre'] == 'Comedies')]
# Out:
#      Category                                      title  \
# 584     Movie                     Not Another Teen Movie
# 1083    Movie                               The Stand-In
# 1389    Movie                              Friendsgiving
# 1515    Movie                                Guest House
# 1729    Movie                           The Late Bloomer
# 1881    Movie               American Pie 9: Girls' Rules
# 2072    Movie                                  Sex Drive
# 2115    Movie                              Drunk Parents
# 2172    Movie                         Killing Hasselhoff
# 2680    Movie                     Puerto Ricans in Paris
# 2809    Movie                               Search Party
# 3073    Movie                       Road Trip: Beer Pong
# 3309    Movie                       Undercover Brother 2
# 3841    Movie                               Wine Country
# 6000    Movie                                  21 & Over
# 6340    Movie  Blue Mountain State: The Rise of Thadland
# 6583    Movie                         Death at a Funeral
# 7015    Movie                         How to Be a Player
# 7365    Movie              Mac & Devin Go to High School
# 7515    Movie                                   Movie 43
# 7566    Movie                    Natural Born Pranksters
# 8087    Movie                              Step Brothers
# 8325    Movie            The Goods: Live Hard, Sell Hard
# 8730    Movie                          Where's the Money
#
#                                                director  \
# 584                                         Joel Gallen
# 1083                                       Jamie Babbit
# 1389                                        Nicol Paone
# 1515                                       Sam Macaroni
# 1729                                       Kevin Pollak
# 1881                                       Mike Elliott
# 2072                                        Sean Anders
# 2115                                          Fred Wolf
# 2172                                       Darren Grant
# 2680                                        Ian Edelman
# 2809                                     Scot Armstrong
# 3073                                         Steve Rash
# 3309                                       Leslie Small
# 3841                                        Amy Poehler
# 6000                             Jon Lucas, Scott Moore
# 6340                                       Lev L. Spiro
# 6583                                        Neil LaBute
# 7015                                   Lionel C. Martin
# 7365                                     Dylan C. Brown
# 7515  Peter Farrelly, Will Graham, Steve Carr, Griff...
# 7566                          Roman Atwood, Ben Pluimer
# 8087                                         Adam McKay
# 8325                                       Neal Brennan
# 8743                   Dramas, Independent Movies          1        2020
# 8757                   Action & Adventure, Dramas         20        2019
# 8766            Action & Adventure, Sports Movies          1        2019
# 8767                           Action & Adventure          1        2019
# 8782  Comedies, Horror Movies, Independent Movies          2        2016
#
#       month_added  Duration_number Unit
# 0               9               90  min
# 9               9              104  min
# 27              9              103  min
# 28              9               97  min
# 29              9              106  min
# ...           ...              ...  ...
# 8743            9              105  min
# 8757           11              129  min
# 8766            1              124  min
# 8767            1              101  min
# 8782           12               88  min
#
# [399 rows x 15 columns]

# %%
len(grouped_movies)
Percentage_of_grouped_movies = 403/8807*100
print(Percentage_of_grouped_movies)
# Out:
# 4.575905529692291

# %%
Steven_Spielberg_movies = netflix_movies_df[netflix_movies_df['director']=='Steven Spielberg']
martin_scorsese_movies = netflix_movies_df[netflix_movies_df['director']=='Martin Scorsese']
Christopher_Nolan_movies = netflix_movies_df[netflix_movies_df['director']=='Christopher Nolan']

# %%
diCaprio_movies = netflix_movies_df[netflix_movies_df['cast']=='Leonardo DiCaprio']

# %%
Christopher_Nolan_movies
# Out:
#     Category      title           director  \
# 340    Movie  Inception  Christopher Nolan
#
#                                                   cast  \
# 340  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                            country date_added  release_year rating duration  \
# 340  United States, United Kingdom 2021-08-01          2010  PG-13  148 min
#
#                                                Genre  day_added  year_added  \
# 340  Action & Adventure, Sci-Fi & Fantasy, Thrillers          1        2021
#
#      month_added  Duration_number Unit
# 340            8              148  min

# %%
martin_scorsese_movies
# Out:
#      Category                                              title  \
# 1358    Movie                                     Shutter Island
# 2632    Movie                       No Direction Home: Bob Dylan
# 2860    Movie                                               Hugo
# 3227    Movie                                       The Irishman
# 3759    Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 6111    Movie                    Alice Doesn't Live Here Anymore
# 6826    Movie                                  Gangs of New York
# 6880    Movie                                         GoodFellas
# 7431    Movie                                       Mean Streets
# 7820    Movie                                        Raging Bull
# 8272    Movie                                       The Departed
# 8735    Movie                    Who's That Knocking at My Door?
#
#              director                                               cast  \
# 1358  Martin Scorsese  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 2632  Martin Scorsese  Bob Dylan, Joan Baez, Dave Van Ronk, Peter Yar...
# 2860  Martin Scorsese  Ben Kingsley, Sacha Baron Cohen, Asa Butterfie...
# 3227  Martin Scorsese  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...
# 3759  Martin Scorsese  Bob Dylan, Allen Ginsberg, Joan Baez, Patti Sm...
# 6111  Martin Scorsese  Ellen Burstyn, Kris Kristofferson, Billy Green...
# 6826  Martin Scorsese  Leonardo DiCaprio, Daniel Day-Lewis, Cameron D...
# 6880  Martin Scorsese  Robert De Niro, Ray Liotta, Joe Pesci, Lorrain...
# 7431  Martin Scorsese  Robert De Niro, Harvey Keitel, David Proval, A...
# 7820  Martin Scorsese  Robert De Niro, Cathy Moriarty, Joe Pesci, Fra...
# 8272  Martin Scorsese  Leonardo DiCaprio, Matt Damon, Jack Nicholson,...
# 8696  Steven Spielberg  Emily Watson, David Thewlis, Peter Mullan, Nie...
#
#                                          country date_added  release_year  \
# 41                                 United States 2021-09-16          1975
# 329                        United States, Canada 2021-08-01          2002
# 1203        United States, India, United Kingdom 2021-03-15          2016
# 7070                               United States 2019-01-01          2008
# 7071                               United States 2019-01-01          1989
# 7072                               United States 2019-01-01          1981
# 7073                               United States 2019-01-01          1984
# 7308                        United States, India 2018-02-21          2012
# 7957                               United States 2018-04-01          1993
# 8184  United States, New Zealand, United Kingdom 2019-11-20          2011
# 8696                        United States, India 2019-05-06          2011
#
#      rating duration                                              Genre  \
# 41       PG  124 min         Action & Adventure, Classic Movies, Dramas
# 329   PG-13  142 min                                             Dramas
# 1203     PG  118 min                   Children & Family Movies, Dramas
# 7070  PG-13  123 min  Action & Adventure, Children & Family Movies, ...
# 7071  PG-13  127 min  Action & Adventure, Children & Family Movies, ...
# 7072     PG  116 min  Action & Adventure, Children & Family Movies, ...
# 7073     PG  119 min  Action & Adventure, Children & Family Movies, ...
# 7308  PG-13  150 min                                             Dramas
# 7957      R  195 min                             Classic Movies, Dramas
# 8184     PG  107 min                           Children & Family Movies
# 8696  PG-13  147 min                                             Dramas
#
#       day_added  year_added  month_added  Duration_number Unit
# 41           16        2021            9              124  min
# 329           1        2021            8              142  min
# 1203         15        2021            3              118  min
# 7070          1        2019            1              123  min
# 7071          1        2019            1              127  min
# 7072          1        2019            1              116  min
# 7073          1        2019            1              119  min
# 7308         21        2018            2              150  min
# 7957          1        2018            4              195  min
# 8184         20        2019           11              107  min
# 8696          6        2019            5              147  min

# %%
#best movies contains movies directed by some outstandig directors
best_movies = netflix_movies_df[(netflix_movies_df['director'].isin(['Martin Scorsese', 'Steven Spielberg', 'Christopher Nolan'])) &
                                 (netflix_movies_df['title'].isin(['Shutter Island', 'Gangs of New York', 'Inception', "Schindler's List"]))]

# %%
best_movies
# Out:
#      Category              title           director  \
# 340     Movie          Inception  Christopher Nolan
# 1358    Movie     Shutter Island    Martin Scorsese
# 6826    Movie  Gangs of New York    Martin Scorsese
# 7957    Movie   Schindler's List   Steven Spielberg
#
#                                                    cast  \
# 340   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 6826  Leonardo DiCaprio, Daniel Day-Lewis, Cameron D...
# 7957  Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...
#
#                             country date_added  release_year rating duration  \
# 340   United States, United Kingdom 2021-08-01          2010  PG-13  148 min
# 1358                  United States 2021-02-01          2010      R  139 min
# 6826           United States, Italy 2019-08-20          2002      R  167 min
# 7957                  United States 2018-04-01          1993      R  195 min
#
#                                                 Genre  day_added  year_added  \
# 340   Action & Adventure, Sci-Fi & Fantasy, Thrillers          1        2021
# 1358                                        Thrillers          1        2021
# 6826                                           Dramas         20        2019
# 7957                           Classic Movies, Dramas          1        2018
#
#       month_added  Duration_number Unit
# 340             8              148  min
# 1358            2              139  min
# 6826            8              167  min
# 7957            4              195  min

# %%
best_movies['director'].value_counts().plot(kind='bar')

# %%
netflix_movies_df.head()
# Out:
#   Category                          title         director  \
# 0    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show                  Blood & Water          Unknown
# 4  TV Show                   Kota Factory          Unknown
# 7    Movie                        Sankofa     Haile Gerima
# 8  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 0                                            Unknown
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# 0                                      United States 2021-09-25          2020
# 1                                       South Africa 2021-09-24          2021
# 4                                              India 2021-09-24          2021
# 7  United States, Ghana, Burkina Faso, United Kin... 2021-09-24          1993
# 8                                     United Kingdom 2021-09-24          2021
#
#   rating   duration                                              Genre  \
# 0  PG-13     90 min                                      Documentaries
# 1  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 4  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# 7  TV-MA    125 min   Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                       British TV Shows, Reality TV
#
#    day_added  year_added  month_added  Duration_number     Unit
# 0         25        2021            9               90      min
# 1         24        2021            9                2  Seasons
# 4         24        2021            9                2  Seasons
# 7         24        2021            9              125      min
# 8         24        2021            9                9  Seasons

# %%
Indian_short_tv_shows = netflix_movies_df[(netflix_movies_df['Duration_number'] <= 2) & (netflix_movies_df['country'] == 'India')]

# %%
Indian_short_tv_shows
# Out:
#      Category                                  title       director  \
# 4     TV Show                           Kota Factory        Unknown
# 50    TV Show                          Dharmakshetra        Unknown
# 66    TV Show          Raja Rasoi Aur Anya Kahaniyan        Unknown
# 69    TV Show         Stories by Rabindranath Tagore        Unknown
# 266   TV Show                   The Creative Indians        Unknown
# ...       ...                                    ...            ...
# 8172  TV Show  Th Eena Meena Deeka Chase Comedy Show  Dheeraj Berry
# 8173  TV Show                              Thackeray        Unknown
# 8235  TV Show                            The Calling          Bumpy
# 8321  TV Show     The Golden Years with Javed Akhtar        Unknown
# 8775  TV Show                        Yeh Meri Family        Unknown
#
#                                                    cast country date_added  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India 2021-09-24
# 50    Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India 2021-09-15
# 66                                              Unknown   India 2021-09-15
# 69                                              Unknown   India 2021-09-15
# 266                                             Unknown   India 2021-08-15
# ...                                                 ...     ...        ...
# 8172                           Sanjay Keni, Priya Raina   India 2018-03-31
# 8173                                            Unknown   India 2019-05-25
# 8235                                            Unknown   India 2019-04-01
# 8321                                            Unknown   India 2017-06-01
# 8775  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...   India 2018-08-31
#
#       release_year rating   duration  \
# 4             2021  TV-MA  2 Seasons
# 50            2014  TV-PG   1 Season
# 66            2014   TV-G   1 Season
# 69            2015  TV-PG   1 Season
# 266           2020  TV-MA   1 Season
# ...            ...    ...        ...
# 8172          2015  TV-Y7   1 Season
# 8173          2019  TV-MA   1 Season
# 8235          2018  TV-MA   1 Season
# 8321          2016   TV-G   1 Season
# 8775          2018  TV-PG   1 Season
#
#                                                   Genre  day_added  \
# 4     International TV Shows, Romantic TV Shows, TV ...         24
# 50    International TV Shows, TV Dramas, TV Sci-Fi &...         15
# 66                   Docuseries, International TV Shows         15
# 69                    International TV Shows, TV Dramas         15
# 266                  Docuseries, International TV Shows         15
# ...                                                 ...        ...
# 8172                              Kids' TV, TV Comedies         31
# 8173                                           TV Shows         25
# 8235                 International TV Shows, Reality TV          1
# 8321                 Docuseries, International TV Shows          1
# 8775                International TV Shows, TV Comedies         31
#
#       year_added  month_added  Duration_number     Unit
# 4           2021            9                2  Seasons
# 50          2021            9                1   Season
# 66          2021            9                1   Season
# 69          2021            9                1   Season
# 266         2021            8                1   Season
# ...          ...          ...              ...      ...
# 8172        2018            3                1   Season
# 8173        2019            5                1   Season
# 8235        2019            4                1   Season
# 8321        2017            6                1   Season
# 8775        2018            8                1   Season
#
# [75 rows x 15 columns]

# %% [markdown]
# # **Data Visualization**

# %%
sns.boxplot(x=netflix_movies_df['release_year'])

# %%
sns.boxplot(x=netflix_movies_df['month_added'])

# %%
netflix_movies_df.hist(figsize=(8,6), bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f250fe2b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2511a92160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2512082be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25160bd700>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f25101723d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f251092a5e0>]],
#       dtype=object)

# %%
netflix_movies_df = netflix_movies_df[(netflix_movies_df != 'unknown').all(axis=1)]

# %%
# Group the data by director and count the number of movies for each director
director_counts = netflix_movies_df.groupby('director').size().sort_values(ascending=False)[:5]

# Pivot the data to create a table with directors as rows and release year as columns
table = pd.pivot_table(netflix_movies_df[netflix_movies_df['director'].isin(director_counts.index)],
                       index='director', columns='release_year', values='title', aggfunc='count', fill_value=0)

# Create a heatmap of the table
sns.heatmap(table, cmap='Blues')

# Set the title and axis labels
plt.title('Top 5 Directors by Number of Movies')
plt.xlabel('Release Year')
plt.ylabel('Director')

# Display the heatmap
plt.show()

# %%
# Create a pivot table with release year as rows, country as columns, and count of movies with duration greater than 120 minutes
table = pd.pivot_table(netflix_movies_df[netflix_movies_df['Genre'] =='Action & Adventure'],
                       index='release_year', columns='country', values='title', aggfunc='count', fill_value=0)

# Create a heatmap of the pivot table
sns.heatmap(table, cmap='Greens')

# Set the title and axis labels
plt.title('Movies Category by Release Year and Country')
plt.xlabel('Country')
plt.ylabel('Release Year')

# Display the heatmap
plt.show()

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 8), dpi=80)
sns.countplot(netflix_movies_df['rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.catplot(x='rating', col='Category', data=netflix_movies_df, kind='count')
g.set_xticklabels(rotation=45)
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Relation between Type and Rating')
plt.show()

# %%
plt.figure(figsize=(12,6))

# Get the value counts for the top 10 countries
top_countries = netflix_movies_df['country'].value_counts().head(10)

# Create a count plot of country vs category with hue
sns.countplot(x='country', hue='Category', data=netflix_movies_df[netflix_movies_df['country'].isin(top_countries.index)])

# Add a title
plt.title('Relation between Category and Top 10 Country ')

# Show the plot
plt.show()

# %%
# First, we need to group the data by director and count the number of movies each director has directed

director_counts = netflix_movies_df.groupby('director').count()['title'].sort_values(ascending=False)

# Get the top 10 directors by count
top_10_directors = director_counts[:10]

# Plot the bar graph
plt.figure(figsize=(12, 8), dpi=80)
sns.barplot(x=top_10_directors.values, y=top_10_directors.index)

# Add labels and titles to the plot
plt.xlabel('Number of Movies Directed')
plt.ylabel('Director')
plt.title('Top 10 Directors by Number of Movies Directed')

# Show the plot
plt.show()

# %%
# First, we need to group the data by country and count the number of movies each country has produced
country_counts = netflix_movies_df.groupby('country').count()['title'].sort_values(ascending=False)

# Get the top 5 countries by count
top_5_countries = country_counts[:5]

# Plot the bar graph
plt.figure(figsize=(8, 6), dpi=80)
sns.barplot(x=top_5_countries.index, y=top_5_countries.values)

# Add labels and titles to the plot
plt.xlabel('Country')
plt.ylabel('Number of Movies Produced')
plt.title('Top 5 Countries by Number of Movies Produced')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 8), dpi=80)
sns.countplot(x='release_year', data=netflix_movies_df[netflix_movies_df['release_year'] > 1998])

# %%
# correlation graph
plt.figure(figsize=(12,10))
sns.heatmap(netflix_movies_df.corr(), annot=True)
plt.title('correlation', fontweight='bold', fontsize=14)
plt.show()

# %%
colors = []

# Iterate over rows of netflix_movies_col_subset
for row, ser in netflix_movies_df.iterrows():
    if ser['rating'] == 'R':
        colors.append('red')
    elif ser['rating'] == 'TV-14' :
        colors.append('blue')
    elif ser['rating'] == "PG-13" :
        colors.append('green')
    else:
        colors.append('black')
        
# Inspect the first 10 values in your list        
print(colors[:11])
# Out:
# ['green', 'black', 'black', 'black', 'blue', 'green', 'black', 'black', 'black', 'blue', 'blue']

# %%
# Create a figure with a own size
fig, ax = plt.subplots(figsize=(10, 6))

# Create a scatter plot of rating versus year
ax.scatter(netflix_movies_df.release_year, netflix_movies_df.rating, c=colors)

# Set the x and y axis labels
ax.set_xlabel('Year of Release')
ax.set_ylabel('Rating')

# Create a title
ax.set_title("Rating by Year of Release")

# Show the plot
plt.show()

# %%
# Filter the dataframe to only include rows with "United States" in the "country" column
us_movies_df = netflix_movies_df[netflix_movies_df['country'] == 'United States']

# Create a scatter plot of rating versus year
plt.scatter(us_movies_df.Duration_number, us_movies_df.rating,)

# Set the x and y axis labels
plt.xlabel('Duration of number (if it is less than 10, it will be a TV SHOW)')
plt.ylabel('Rating')

# Create a title
plt.title("Rating by Duration (United States)")

# Show the plot
plt.show()

# %%
netflix_movies_df['rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(12,10))
plt.title('Part of Rating', fontsize = 17)
plt.show()

# %%
 # Top 10 Country which have highest Movie and TV Show
 lb = netflix_movies_df['country'].value_counts().head(10)
 labels = lb.index
 plt.figure(figsize=(12,10))
 plt.pie(netflix_movies_df['country'].value_counts().head(10),labels= labels, autopct='%.2f%%', startangle=75)
 plt.title('Top 10 Country', fontweight='bold', fontsize=14)
 plt.legend()
 plt.legend(loc="upper left")
 plt.show()

# %%
 # Top 10 Release Year
 lb = netflix_movies_df['release_year'].value_counts().head(10)
 labels = lb.index
 plt.figure(figsize=(12,10))
 plt.pie(netflix_movies_df['release_year'].value_counts().head(10),labels= labels, autopct='%.2f%%', startangle=75)
 plt.title('Top 5 Release Year', fontweight='bold', fontsize=12)
 plt.legend()
 plt.legend(loc="upper right")
 plt.show()

# %% [markdown]
# # **Predictions**
